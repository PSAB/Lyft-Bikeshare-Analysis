# %% [markdown]
# # Analysis of August 2019 Lyft Bikeshare Rides
# ## By Pavan Sabnis
#
# > This dataset includes Lyft's bikeshare trip data for public use. Each entry is a ride by a customer using bicycles that are part of Lyft's bikeshare program

# %% [markdown]
# ## Investigation Overview
#
# > In this Lyft dataset, the best dependent variable 'to be predicted' in my view would be the end station. Performing an analysis centered on where the user is most likely to travel would be ideal, so that Lyft would know to take action such as include additional bikes at a frequent station, remove stations that are less profitable to maintain, or even include promotions/deals for the user if there happens to be a popular business/destination near where the end station is situated.<br><br>
# In addition, however, it is best in general to gain insight into behaviors patterns, or tendencies of the bikeshare users through this data; Understanding this will overall help make better decisions regarding consumer preferences.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %matplotlib inline

# %%
bikeshare_data = pd.read_csv('201908-baywheels-tripdata.csv')

# %% [markdown]
# This data was measured over the course of August 2019.

# %%
bikeshare_data.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         68145  2019-08-31 21:27:42.2530  2019-09-01 16:23:27.4920
# 1         53216  2019-08-31 22:34:17.5120  2019-09-01 13:21:13.9310
# 2         53182  2019-08-31 22:34:49.9420  2019-09-01 13:21:12.4570
# 3         75682  2019-08-31 14:22:02.2780  2019-09-01 11:23:24.5110
# 4         30849  2019-08-31 18:47:08.0570  2019-09-01 03:21:17.6970
#
#    start_station_id         start_station_name  start_station_latitude  \
# 0               249  Russell St at College Ave               37.858473
# 1               368       Myrtle St at Polk St               37.785434
# 2               368       Myrtle St at Polk St               37.785434
# 3               104          4th St at 16th St               37.767045
# 4               327  5th St at San Salvador St               37.332039
#
#    start_station_longitude  end_station_id           end_station_name  \
# 0              -122.253253             247  Fulton St at Bancroft Way
# 1              -122.419622              78        Folsom St at 9th St
# 2              -122.419622              78        Folsom St at 9th St
# 3              -122.390833             126                Esprit Park
# 4              -121.881766             327  5th St at San Salvador St
#
#    end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0             37.867789            -122.265896     3112    Customer
# 1             37.773717            -122.411647     2440    Customer
# 2             37.773717            -122.411647     9743    Customer
# 3             37.761634            -122.390648    11418  Subscriber
# 4             37.332039            -121.881766     1553    Customer
#
#    member_birth_year member_gender bike_share_for_all_trip
# 0                NaN           NaN                      No
# 1             1993.0        Female                      No
# 2             1995.0          Male                      No
# 3             1993.0        Female                      No
# 4                NaN           NaN                      No

# %%
bikeshare_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210563 entries, 0 to 210562
# Data columns (total 16 columns):
# duration_sec               210563 non-null int64
# start_time                 210563 non-null object
# end_time                   210563 non-null object
# start_station_id           210563 non-null int64
# start_station_name         210563 non-null object
# start_station_latitude     210563 non-null float64
# start_station_longitude    210563 non-null float64
# end_station_id             210563 non-null int64
# end_station_name           210563 non-null object
# end_station_latitude       210563 non-null float64
# end_station_longitude      210563 non-null float64
# bike_id                    210563 non-null int64
# user_type                  210563 non-null object
# member_birth_year          170774 non-null float64
# member_gender              170777 non-null object
# bike_share_for_all_trip    210563 non-null object
# dtypes: float64(5), int64(4), object(7)
# memory usage: 25.7+ MB

# %% [markdown]
# <br>
# Right away, I notice that member_birth_year and member_gender contain null data. The obvious explanation would be that the participants chose not to include their sensitive information as part of the service or study. But just to be clear, let's examine those specific null data entries to see any patterns:<br>

# %%
null_compare_or = bikeshare_data[(bikeshare_data['member_birth_year'].isnull()) | (bikeshare_data['member_gender'].isnull())]
null_compare_and = bikeshare_data[(bikeshare_data['member_birth_year'].isnull()) & (bikeshare_data['member_gender'].isnull())]

# %%
null_compare_or
# Out:
#         duration_sec                start_time                  end_time  \
# 0              68145  2019-08-31 21:27:42.2530  2019-09-01 16:23:27.4920
# 4              30849  2019-08-31 18:47:08.0570  2019-09-01 03:21:17.6970
# 5              17193  2019-08-31 20:52:40.7440  2019-09-01 01:39:14.5920
# 7               9528  2019-08-31 22:04:15.4460  2019-09-01 00:43:03.8740
# 8               9542  2019-08-31 22:03:56.5060  2019-09-01 00:42:59.3280
# 9               4121  2019-08-31 23:26:05.7510  2019-09-01 00:34:46.8930
# 23              1545  2019-08-31 23:36:30.8180  2019-09-01 00:02:16.5230
# 25              1328  2019-08-31 23:38:52.1400  2019-09-01 00:01:00.2100
# 28               609  2019-08-31 23:47:21.4230  2019-08-31 23:57:31.0430
# 29               613  2019-08-31 23:47:16.0480  2019-08-31 23:57:29.5280
# 30              1181  2019-08-31 23:37:11.0880  2019-08-31 23:56:52.2240
# 31              1144  2019-08-31 23:36:46.6690  2019-08-31 23:55:51.1650
# 37               554  2019-08-31 23:39:30.8880  2019-08-31 23:48:44.9140
# 38               441  2019-08-31 23:40:32.0350  2019-08-31 23:47:53.2010
# 40               300  2019-08-31 23:41:48.8070  2019-08-31 23:46:48.8760
# 42               185  2019-08-31 23:41:59.2880  2019-08-31 23:45:05.1890
# 43              1846  2019-08-31 23:13:04.3130  2019-08-31 23:43:50.8720
# 45               711  2019-08-31 23:31:15.5500  2019-08-31 23:43:07.4410
# 48              1001  2019-08-31 23:22:07.1900  2019-08-31 23:38:48.7710
# 57               679  2019-08-31 23:21:54.5210  2019-08-31 23:33:14.3210
# 60               343  2019-08-31 23:24:13.9750  2019-08-31 23:29:57.2190
# 66               581  2019-08-31 23:15:16.1750  2019-08-31 23:24:57.2760
# 67               609  2019-08-31 23:14:43.2810  2019-08-31 23:24:52.4770
# 70               411  2019-08-31 23:14:29.9040  2019-08-31 23:21:21.6100
# 76              2826  2019-08-31 22:28:50.7290  2019-08-31 23:15:57.3850
# 77              2806  2019-08-31 22:28:05.8070  2019-08-31 23:14:52.0730
# 78              1135  2019-08-31 22:55:43.3610  2019-08-31 23:14:39.0770
# 84               653  2019-08-31 22:58:26.2620  2019-08-31 23:09:19.3460
# 91              1211  2019-08-31 22:45:54.8300  2019-08-31 23:06:06.7000
# 97              6099  2019-08-31 21:16:38.7090  2019-08-31 22:58:17.9730
# ...              ...                       ...                       ...
# 210391           457  2019-08-01 06:29:23.4670  2019-08-01 06:37:00.7860
# 210398           387  2019-08-01 06:28:08.1400  2019-08-01 06:34:35.3440
# 210403           209  2019-08-01 06:28:07.1380  2019-08-01 06:31:36.4390
# 210422           275  2019-08-01 06:20:43.7620  2019-08-01 06:25:19.1180
# 210425           570  2019-08-01 06:14:44.9590  2019-08-01 06:24:15.3710
# 210432           479  2019-08-01 06:13:42.9300  2019-08-01 06:21:42.3470
# 210435           510  2019-08-01 06:11:59.2010  2019-08-01 06:20:29.4210
# 210437           421  2019-08-01 06:13:01.4350  2019-08-01 06:20:02.5870
# 210447           437  2019-08-01 06:06:30.1550  2019-08-01 06:13:47.8920
# 210453           941  2019-08-01 05:51:29.4440  2019-08-01 06:07:11.0020
# 210457           357  2019-08-01 05:59:58.0260  2019-08-01 06:05:55.6870
# 210458           830  2019-08-01 05:51:30.2680  2019-08-01 06:05:21.1530
# 210472           657  2019-08-01 05:46:49.2760  2019-08-01 05:57:47.0390
# 210474           710  2019-08-01 05:42:07.7430  2019-08-01 05:53:58.0770
# 210476           317  2019-08-01 05:47:57.8640  2019-08-01 05:53:15.6120
# 210504          4294  2019-08-01 03:13:51.2950  2019-08-01 04:25:25.7520
# 210505          4107  2019-08-01 03:16:56.0500  2019-08-01 04:25:23.2270
# 210506          1872  2019-08-01 03:49:30.9360  2019-08-01 04:20:43.3440
# 210511          1061  2019-08-01 03:24:17.3140  2019-08-01 03:41:58.3890
# 210512          2795  2019-08-01 02:50:53.8920  2019-08-01 03:37:29.3620
# 210514          1325  2019-08-01 03:07:24.1240  2019-08-01 03:29:29.7600
# 210515           220  2019-08-01 03:17:12.5100  2019-08-01 03:20:53.2250
# 210518           537  2019-08-01 02:47:23.4280  2019-08-01 02:56:21.2090
# 210519           633  2019-08-01 02:44:36.6500  2019-08-01 02:55:10.0040
# 210525           278  2019-08-01 02:10:16.1050  2019-08-01 02:14:54.5500
# 210534           603  2019-08-01 00:58:06.8140  2019-08-01 01:08:09.9020
# 210542          1869  2019-08-01 00:12:22.3800  2019-08-01 00:43:32.1770
# 210545           548  2019-08-01 00:21:20.3830  2019-08-01 00:30:28.9080
# 210548           680  2019-08-01 00:17:22.3420  2019-08-01 00:28:42.4590
# 210554           582  2019-08-01 00:13:55.8090  2019-08-01 00:23:37.9480
#
#         start_station_id                                 start_station_name  \
# 0                    249                          Russell St at College Ave
# 4                    327                          5th St at San Salvador St
# 5                     49                                S Park St at 3rd St
# 7                    160                          West Oakland BART Station
# 8                    160                          West Oakland BART Station
# 9                      5       Powell St BART Station (Market St at 5th St)
# 23                   282                               Market St at Park St
# 25                    17   Embarcadero BART Station (Beale St at Market St)
# 28                    98                             Valencia St at 16th St
# 29                    98                             Valencia St at 16th St
# 30                    58                               Market St at 10th St
# 31                    58                               Market St at 10th St
# 37                    98                             Valencia St at 16th St
# 38                    17   Embarcadero BART Station (Beale St at Market St)
# 40                    15  San Francisco Ferry Building (Harry Bridges Pl...
# 42                   417                                Park Ave at Race St
# 43                   282                               Market St at Park St
# 45                   324                Union Square (Powell St at Post St)
# 48                   245                             Downtown Berkeley BART
# 57                   176                             MacArthur BART Station
# 60                   285                         Webster St at O'Farrell St
# 66                   127                             Valencia St at 21st St
# 67                   127                             Valencia St at 21st St
# 70                   127                             Valencia St at 21st St
# 76                    66                              3rd St at Townsend St
# 77                    66                              3rd St at Townsend St
# 78                     5       Powell St BART Station (Market St at 5th St)
# 84                   223                     16th St Mission BART Station 2
# 91                   230                            14th St at Mandela Pkwy
# 97                   197                        El Embarcadero at Grand Ave
# ...                  ...                                                ...
# 210391               365                             Turk St at Fillmore St
# 210398                15  San Francisco Ferry Building (Harry Bridges Pl...
# 210403               175                           49th St at Telegraph Ave
# 210422                28                       The Embarcadero at Bryant St
# 210425               285                         Webster St at O'Farrell St
# 210432               365                             Turk St at Fillmore St
# 210435                 4                        Cyril Magnin St at Ellis St
# 210437                92                              Mission Bay Kids Park
# 210447                67  San Francisco Caltrain Station 2  (Townsend St...
# 210453                84                                        Duboce Park
# 210457                29                      O'Farrell St at Divisadero St
# 210458               262                          West St at University Ave
# 210472               398                         Leavenworth St at Broadway
# 210474                17   Embarcadero BART Station (Beale St at Market St)
# 210476                67  San Francisco Caltrain Station 2  (Townsend St...
# 210504               426                      San Carlos St at Meridian Ave
# 210505               426                      San Carlos St at Meridian Ave
# 210506               155                           Emeryville Public Market
# 210511               397                                  Gish Rd at 1st St
# 210512               148                               Horton St at 40th St
# 210514                60                               8th St at Ringold St
# 210515               269                       Telegraph Ave at Carleton St
# 210518                74                              Laguna St at Hayes St
# 210519               119                                  18th St at Noe St
# 210525                62                        Victoria Manalo Draves Park
# 210534                98                             Valencia St at 16th St
# 210542               144                                       Precita Park
# 210545                62                        Victoria Manalo Draves Park
# 210548               312                           San Jose Diridon Station
# 210554               223                     16th St Mission BART Station 2
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.858473              -122.253253             247
# 4                    37.332039              -121.881766             327
# 5                    37.780760              -122.394989               3
# 7                    37.805318              -122.294837             237
# 8                    37.805318              -122.294837             237
# 9                    37.783899              -122.408445               4
# 23                   37.332426              -121.890349             282
# 25                   37.792251              -122.397086              55
# 28                   37.765052              -122.421866             411
# 29                   37.765052              -122.421866             411
# 30                   37.776619              -122.417385             106
# 31                   37.776619              -122.417385             106
# 37                   37.765052              -122.421866             411
# 38                   37.792251              -122.397086               3
# 40                   37.795392              -122.394203              27
# 42                   37.326011              -121.912327             417
# 43                   37.332426              -121.890349             282
# 45                   37.788300              -122.408531              44
# 48                   37.870139              -122.268422             271
# 57                   37.828410              -122.266315             156
# 60                   37.783521              -122.431158              74
# 66                   37.756708              -122.421025             411
# 67                   37.756708              -122.421025             411
# 70                   37.756708              -122.421025             147
# 76                   37.778742              -122.392741              37
# 77                   37.778742              -122.392741              37
# 78                   37.783899              -122.408445             122
# 84                   37.764765              -122.420091             141
# 91                   37.810743              -122.291415             176
# 97                   37.808848              -122.249680             182
# ...                        ...                      ...             ...
# 210391               37.780450              -122.431946              42
# 210398               37.795392              -122.394203               6
# 210403               37.835946              -122.262366             176
# 210422               37.787168              -122.388098              27
# 210425               37.783521              -122.431158              75
# 210432               37.780450              -122.431946              33
# 210435               37.785881              -122.408915              67
# 210437               37.772301              -122.393028             116
# 210447               37.776639              -122.395526             114
# 210453               37.769201              -122.433812              95
# 210457               37.782405              -122.439446              73
# 210458               37.869967              -122.286533             252
# 210472               37.796471              -122.416858              21
# 210474               37.792251              -122.397086              28
# 210476               37.776639              -122.395526              90
# 210504               37.323345              -121.913497             406
# 210505               37.323345              -121.913497             406
# 210506               37.840521              -122.293528             148
# 210511               37.361867              -121.909315             278
# 210512               37.829705              -122.287610             155
# 210514               37.774520              -122.409449             386
# 210515               37.862320              -122.258801             242
# 210518               37.776435              -122.426244              98
# 210519               37.761047              -122.432642              56
# 210525               37.777791              -122.406432              36
# 210534               37.765052              -122.421866               5
# 210542               37.747300              -122.411403             144
# 210545               37.777791              -122.406432              97
# 210548               37.329732              -121.901782             310
# 210554               37.764765              -122.420091             356
#
#                                          end_station_name  \
# 0                               Fulton St at Bancroft Way
# 4                               5th St at San Salvador St
# 5            Powell St BART Station (Market St at 4th St)
# 7                                  Fruitvale BART Station
# 8                                  Fruitvale BART Station
# 9                             Cyril Magnin St at Ellis St
# 23                                   Market St at Park St
# 25                                 Webster St at Grove St
# 28                                Octavia Blvd at Page St
# 29                                Octavia Blvd at Page St
# 30                                  Sanchez St at 17th St
# 31                                  Sanchez St at 17th St
# 37                                Octavia Blvd at Page St
# 38           Powell St BART Station (Market St at 4th St)
# 40                                Beale St at Harrison St
# 42                                    Park Ave at Race St
# 43                                   Market St at Park St
# 45      Civic Center/UN Plaza BART Station (Market St ...
# 48                                         San Pablo Park
# 57                              Stanford Ave at Hollis St
# 60                                  Laguna St at Hayes St
# 66                                Octavia Blvd at Page St
# 67                                Octavia Blvd at Page St
# 70                                 29th St at Tiffany Ave
# 76                                    Folsom St at 2nd St
# 77                                    Folsom St at 2nd St
# 78                                  19th St at Mission St
# 84                         Valencia St at Cesar Chavez St
# 91                                 MacArthur BART Station
# 97                               19th Street BART Station
# ...                                                   ...
# 210391      San Francisco City Hall (Polk St at Grove St)
# 210398                      The Embarcadero at Sansome St
# 210403                             MacArthur BART Station
# 210422                            Beale St at Harrison St
# 210425                           Market St at Franklin St
# 210432                         Golden Gate Ave at Hyde St
# 210435  San Francisco Caltrain Station 2  (Townsend St...
# 210437                          Mississippi St at 17th St
# 210447                         Rhode Island St at 17th St
# 210453                              Sanchez St at 15th St
# 210457                             Pierce St at Haight St
# 210458                       Channing Way at Shattuck Ave
# 210472   Montgomery St BART Station (Market St at 2nd St)
# 210474                       The Embarcadero at Bryant St
# 210476                              Townsend St at 7th St
# 210504                            Parkmoor Ave at Race St
# 210505                            Parkmoor Ave at Race St
# 210506                               Horton St at 40th St
# 210511                             The Alameda at Bush St
# 210512                           Emeryville Public Market
# 210514                             24th St at Bartlett St
# 210515                              Milvia St at Derby St
# 210518                             Valencia St at 16th St
# 210519                                      Koshland Park
# 210525                                Folsom St at 3rd St
# 210534       Powell St BART Station (Market St at 5th St)
# 210542                                       Precita Park
# 210545                              14th St at Mission St
# 210548                          San Fernando St at 4th St
# 210554                        Valencia St at Clinton Park
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0                  37.867789            -122.265896     3112    Customer
# 4                  37.332039            -121.881766     1553    Customer
# 5                  37.786375            -122.404904     3503    Customer
# 7                  37.775232            -122.224498     1577    Customer
# 8                  37.775232            -122.224498     2534    Customer
# 9                  37.785881            -122.408915     9651    Customer
# 23                 37.332426            -121.890349     1838    Customer
# 25                 37.777053            -122.429558      649    Customer
# 28                 37.774018            -122.423809     9807    Customer
# 29                 37.774018            -122.423809    10036    Customer
# 30                 37.763242            -122.430675    11506    Customer
# 31                 37.763242            -122.430675     9789    Customer
# 37                 37.774018            -122.423809    10184    Customer
# 38                 37.786375            -122.404904    11185    Customer
# 40                 37.788059            -122.391865     9959    Customer
# 42                 37.326011            -121.912327    10548    Customer
# 43                 37.332426            -121.890349     9218    Customer
# 45                 37.781074            -122.411738     1586    Customer
# 48                 37.855783            -122.283127     3061    Customer
# 57                 37.838443            -122.288665     1135    Customer
# 60                 37.776435            -122.426244     2299    Customer
# 66                 37.774018            -122.423809     3150    Customer
# 67                 37.774018            -122.423809     9555  Subscriber
# 70                 37.744067            -122.421472    10344  Subscriber
# 76                 37.785377            -122.396906     9774    Customer
# 77                 37.785377            -122.396906      901    Customer
# 78                 37.760299            -122.418892    10046    Customer
# 84                 37.747998            -122.420219     9885    Customer
# 91                 37.828410            -122.266315     1339    Customer
# 97                 37.809013            -122.268247     2447    Customer
# ...                      ...                    ...      ...         ...
# 210391             37.778650            -122.418230      649    Customer
# 210398             37.804770            -122.403234     1651    Customer
# 210403             37.828410            -122.266315     1334  Subscriber
# 210422             37.788059            -122.391865     2848    Customer
# 210425             37.773793            -122.421239      997  Subscriber
# 210432             37.781650            -122.415408     3348    Customer
# 210435             37.776639            -122.395526      651    Customer
# 210437             37.764802            -122.394771     2215  Subscriber
# 210447             37.764478            -122.402570      495    Customer
# 210453             37.766219            -122.431060     1027    Customer
# 210457             37.771793            -122.433708     1759    Customer
# 210458             37.865847            -122.267443     1413    Customer
# 210472             37.789625            -122.400811     2298    Customer
# 210474             37.787168            -122.388098     2357    Customer
# 210476             37.771058            -122.402717     1772  Subscriber
# 210504             37.316736            -121.910005     7158    Customer
# 210505             37.316736            -121.910005     9179    Customer
# 210506             37.829705            -122.287610     3048    Customer
# 210511             37.331932            -121.904888      145    Customer
# 210512             37.840521            -122.293528     1242    Customer
# 210514             37.752105            -122.419724       40    Customer
# 210515             37.860125            -122.269384     1576    Customer
# 210518             37.765052            -122.421866      534    Customer
# 210519             37.773414            -122.427317     3246    Customer
# 210525             37.783830            -122.398870     1048    Customer
# 210534             37.783899            -122.408445      172    Customer
# 210542             37.747300            -122.411403     1890    Customer
# 210545             37.768265            -122.420110     3083    Customer
# 210548             37.335885            -121.885660     7176    Customer
# 210554             37.769188            -122.422285     2826    Customer
#
#         member_birth_year member_gender bike_share_for_all_trip
# 0                     NaN           NaN                      No
# 4                     NaN           NaN                      No
# 5                     NaN           NaN                      No
# 7                     NaN           NaN                      No
# 8                     NaN           NaN                      No
# 9                     NaN           NaN                      No
# 23                    NaN           NaN                      No
# 25                    NaN           NaN                      No
# 28                    NaN           NaN                      No
# 29                    NaN           NaN                      No
# 30                    NaN           NaN                      No
# 31                    NaN           NaN                      No
# 37                    NaN           NaN                      No
# 38                    NaN           NaN                      No
# 40                    NaN           NaN                      No
# 42                    NaN           NaN                      No
# 43                    NaN           NaN                      No
# 45                    NaN           NaN                      No
# 48                    NaN           NaN                      No
# 57                    NaN           NaN                      No
# 60                    NaN           NaN                      No
# 66                    NaN           NaN                      No
# 67                    NaN           NaN                      No
# 70                    NaN           NaN                      No
# 76                    NaN           NaN                      No
# 77                    NaN           NaN                      No
# 78                    NaN           NaN                      No
# 84                    NaN           NaN                      No
# 91                    NaN           NaN                      No
# 97                    NaN           NaN                      No
# ...                   ...           ...                     ...
# 210391                NaN           NaN                      No
# 210398                NaN           NaN                      No
# 210403                NaN           NaN                      No
# 210422                NaN           NaN                      No
# 210425                NaN           NaN                      No
# 210432                NaN           NaN                      No
# 210435                NaN           NaN                      No
# 210437                NaN           NaN                      No
# 210447                NaN           NaN                      No
# 210453                NaN           NaN                      No
# 210457                NaN           NaN                      No
# 210458                NaN           NaN                      No
# 210472                NaN           NaN                      No
# 210474                NaN           NaN                      No
# 210476                NaN           NaN                      No
# 210504                NaN           NaN                      No
# 210505                NaN           NaN                      No
# 210506                NaN           NaN                      No
# 210511                NaN           NaN                      No
# 210512                NaN           NaN                      No
# 210514                NaN           NaN                      No
# 210515                NaN           NaN                      No
# 210518                NaN           NaN                      No
# 210519                NaN           NaN                      No
# 210525                NaN           NaN                      No
# 210534                NaN           NaN                      No
# 210542                NaN           NaN                      No
# 210545                NaN           NaN                      No
# 210548                NaN           NaN                      No
# 210554                NaN           NaN                      No
#
# [39789 rows x 16 columns]

# %%
null_compare_and
# Out:
#         duration_sec                start_time                  end_time  \
# 0              68145  2019-08-31 21:27:42.2530  2019-09-01 16:23:27.4920
# 4              30849  2019-08-31 18:47:08.0570  2019-09-01 03:21:17.6970
# 5              17193  2019-08-31 20:52:40.7440  2019-09-01 01:39:14.5920
# 7               9528  2019-08-31 22:04:15.4460  2019-09-01 00:43:03.8740
# 8               9542  2019-08-31 22:03:56.5060  2019-09-01 00:42:59.3280
# 9               4121  2019-08-31 23:26:05.7510  2019-09-01 00:34:46.8930
# 23              1545  2019-08-31 23:36:30.8180  2019-09-01 00:02:16.5230
# 25              1328  2019-08-31 23:38:52.1400  2019-09-01 00:01:00.2100
# 28               609  2019-08-31 23:47:21.4230  2019-08-31 23:57:31.0430
# 29               613  2019-08-31 23:47:16.0480  2019-08-31 23:57:29.5280
# 30              1181  2019-08-31 23:37:11.0880  2019-08-31 23:56:52.2240
# 31              1144  2019-08-31 23:36:46.6690  2019-08-31 23:55:51.1650
# 37               554  2019-08-31 23:39:30.8880  2019-08-31 23:48:44.9140
# 38               441  2019-08-31 23:40:32.0350  2019-08-31 23:47:53.2010
# 40               300  2019-08-31 23:41:48.8070  2019-08-31 23:46:48.8760
# 42               185  2019-08-31 23:41:59.2880  2019-08-31 23:45:05.1890
# 43              1846  2019-08-31 23:13:04.3130  2019-08-31 23:43:50.8720
# 45               711  2019-08-31 23:31:15.5500  2019-08-31 23:43:07.4410
# 48              1001  2019-08-31 23:22:07.1900  2019-08-31 23:38:48.7710
# 57               679  2019-08-31 23:21:54.5210  2019-08-31 23:33:14.3210
# 60               343  2019-08-31 23:24:13.9750  2019-08-31 23:29:57.2190
# 66               581  2019-08-31 23:15:16.1750  2019-08-31 23:24:57.2760
# 67               609  2019-08-31 23:14:43.2810  2019-08-31 23:24:52.4770
# 70               411  2019-08-31 23:14:29.9040  2019-08-31 23:21:21.6100
# 76              2826  2019-08-31 22:28:50.7290  2019-08-31 23:15:57.3850
# 77              2806  2019-08-31 22:28:05.8070  2019-08-31 23:14:52.0730
# 78              1135  2019-08-31 22:55:43.3610  2019-08-31 23:14:39.0770
# 84               653  2019-08-31 22:58:26.2620  2019-08-31 23:09:19.3460
# 91              1211  2019-08-31 22:45:54.8300  2019-08-31 23:06:06.7000
# 97              6099  2019-08-31 21:16:38.7090  2019-08-31 22:58:17.9730
# ...              ...                       ...                       ...
# 210391           457  2019-08-01 06:29:23.4670  2019-08-01 06:37:00.7860
# 210398           387  2019-08-01 06:28:08.1400  2019-08-01 06:34:35.3440
# 210403           209  2019-08-01 06:28:07.1380  2019-08-01 06:31:36.4390
# 210422           275  2019-08-01 06:20:43.7620  2019-08-01 06:25:19.1180
# 210425           570  2019-08-01 06:14:44.9590  2019-08-01 06:24:15.3710
# 210432           479  2019-08-01 06:13:42.9300  2019-08-01 06:21:42.3470
# 210435           510  2019-08-01 06:11:59.2010  2019-08-01 06:20:29.4210
# 210437           421  2019-08-01 06:13:01.4350  2019-08-01 06:20:02.5870
# 210447           437  2019-08-01 06:06:30.1550  2019-08-01 06:13:47.8920
# 210453           941  2019-08-01 05:51:29.4440  2019-08-01 06:07:11.0020
# 210457           357  2019-08-01 05:59:58.0260  2019-08-01 06:05:55.6870
# 210458           830  2019-08-01 05:51:30.2680  2019-08-01 06:05:21.1530
# 210472           657  2019-08-01 05:46:49.2760  2019-08-01 05:57:47.0390
# 210474           710  2019-08-01 05:42:07.7430  2019-08-01 05:53:58.0770
# 210476           317  2019-08-01 05:47:57.8640  2019-08-01 05:53:15.6120
# 210504          4294  2019-08-01 03:13:51.2950  2019-08-01 04:25:25.7520
# 210505          4107  2019-08-01 03:16:56.0500  2019-08-01 04:25:23.2270
# 210506          1872  2019-08-01 03:49:30.9360  2019-08-01 04:20:43.3440
# 210511          1061  2019-08-01 03:24:17.3140  2019-08-01 03:41:58.3890
# 210512          2795  2019-08-01 02:50:53.8920  2019-08-01 03:37:29.3620
# 210514          1325  2019-08-01 03:07:24.1240  2019-08-01 03:29:29.7600
# 210515           220  2019-08-01 03:17:12.5100  2019-08-01 03:20:53.2250
# 210518           537  2019-08-01 02:47:23.4280  2019-08-01 02:56:21.2090
# 210519           633  2019-08-01 02:44:36.6500  2019-08-01 02:55:10.0040
# 210525           278  2019-08-01 02:10:16.1050  2019-08-01 02:14:54.5500
# 210534           603  2019-08-01 00:58:06.8140  2019-08-01 01:08:09.9020
# 210542          1869  2019-08-01 00:12:22.3800  2019-08-01 00:43:32.1770
# 210545           548  2019-08-01 00:21:20.3830  2019-08-01 00:30:28.9080
# 210548           680  2019-08-01 00:17:22.3420  2019-08-01 00:28:42.4590
# 210554           582  2019-08-01 00:13:55.8090  2019-08-01 00:23:37.9480
#
#         start_station_id                                 start_station_name  \
# 0                    249                          Russell St at College Ave
# 4                    327                          5th St at San Salvador St
# 5                     49                                S Park St at 3rd St
# 7                    160                          West Oakland BART Station
# 8                    160                          West Oakland BART Station
# 9                      5       Powell St BART Station (Market St at 5th St)
# 23                   282                               Market St at Park St
# 25                    17   Embarcadero BART Station (Beale St at Market St)
# 28                    98                             Valencia St at 16th St
# 29                    98                             Valencia St at 16th St
# 30                    58                               Market St at 10th St
# 31                    58                               Market St at 10th St
# 37                    98                             Valencia St at 16th St
# 38                    17   Embarcadero BART Station (Beale St at Market St)
# 40                    15  San Francisco Ferry Building (Harry Bridges Pl...
# 42                   417                                Park Ave at Race St
# 43                   282                               Market St at Park St
# 45                   324                Union Square (Powell St at Post St)
# 48                   245                             Downtown Berkeley BART
# 57                   176                             MacArthur BART Station
# 60                   285                         Webster St at O'Farrell St
# 66                   127                             Valencia St at 21st St
# 67                   127                             Valencia St at 21st St
# 70                   127                             Valencia St at 21st St
# 76                    66                              3rd St at Townsend St
# 77                    66                              3rd St at Townsend St
# 78                     5       Powell St BART Station (Market St at 5th St)
# 84                   223                     16th St Mission BART Station 2
# 91                   230                            14th St at Mandela Pkwy
# 97                   197                        El Embarcadero at Grand Ave
# ...                  ...                                                ...
# 210391               365                             Turk St at Fillmore St
# 210398                15  San Francisco Ferry Building (Harry Bridges Pl...
# 210403               175                           49th St at Telegraph Ave
# 210422                28                       The Embarcadero at Bryant St
# 210425               285                         Webster St at O'Farrell St
# 210432               365                             Turk St at Fillmore St
# 210435                 4                        Cyril Magnin St at Ellis St
# 210437                92                              Mission Bay Kids Park
# 210447                67  San Francisco Caltrain Station 2  (Townsend St...
# 210453                84                                        Duboce Park
# 210457                29                      O'Farrell St at Divisadero St
# 210458               262                          West St at University Ave
# 210472               398                         Leavenworth St at Broadway
# 210474                17   Embarcadero BART Station (Beale St at Market St)
# 210476                67  San Francisco Caltrain Station 2  (Townsend St...
# 210504               426                      San Carlos St at Meridian Ave
# 210505               426                      San Carlos St at Meridian Ave
# 210506               155                           Emeryville Public Market
# 210511               397                                  Gish Rd at 1st St
# 210512               148                               Horton St at 40th St
# 210514                60                               8th St at Ringold St
# 210515               269                       Telegraph Ave at Carleton St
# 210518                74                              Laguna St at Hayes St
# 210519               119                                  18th St at Noe St
# 210525                62                        Victoria Manalo Draves Park
# 210534                98                             Valencia St at 16th St
# 210542               144                                       Precita Park
# 210545                62                        Victoria Manalo Draves Park
# 210548               312                           San Jose Diridon Station
# 210554               223                     16th St Mission BART Station 2
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.858473              -122.253253             247
# 4                    37.332039              -121.881766             327
# 5                    37.780760              -122.394989               3
# 7                    37.805318              -122.294837             237
# 8                    37.805318              -122.294837             237
# 9                    37.783899              -122.408445               4
# 23                   37.332426              -121.890349             282
# 25                   37.792251              -122.397086              55
# 28                   37.765052              -122.421866             411
# 29                   37.765052              -122.421866             411
# 30                   37.776619              -122.417385             106
# 31                   37.776619              -122.417385             106
# 37                   37.765052              -122.421866             411
# 38                   37.792251              -122.397086               3
# 40                   37.795392              -122.394203              27
# 42                   37.326011              -121.912327             417
# 43                   37.332426              -121.890349             282
# 45                   37.788300              -122.408531              44
# 48                   37.870139              -122.268422             271
# 57                   37.828410              -122.266315             156
# 60                   37.783521              -122.431158              74
# 66                   37.756708              -122.421025             411
# 67                   37.756708              -122.421025             411
# 70                   37.756708              -122.421025             147
# 76                   37.778742              -122.392741              37
# 77                   37.778742              -122.392741              37
# 78                   37.783899              -122.408445             122
# 84                   37.764765              -122.420091             141
# 91                   37.810743              -122.291415             176
# 97                   37.808848              -122.249680             182
# ...                        ...                      ...             ...
# 210391               37.780450              -122.431946              42
# 210398               37.795392              -122.394203               6
# 210403               37.835946              -122.262366             176
# 210422               37.787168              -122.388098              27
# 210425               37.783521              -122.431158              75
# 210432               37.780450              -122.431946              33
# 210435               37.785881              -122.408915              67
# 210437               37.772301              -122.393028             116
# 210447               37.776639              -122.395526             114
# 210453               37.769201              -122.433812              95
# 210457               37.782405              -122.439446              73
# 210458               37.869967              -122.286533             252
# 210472               37.796471              -122.416858              21
# 210474               37.792251              -122.397086              28
# 210476               37.776639              -122.395526              90
# 210504               37.323345              -121.913497             406
# 210505               37.323345              -121.913497             406
# 210506               37.840521              -122.293528             148
# 210511               37.361867              -121.909315             278
# 210512               37.829705              -122.287610             155
# 210514               37.774520              -122.409449             386
# 210515               37.862320              -122.258801             242
# 210518               37.776435              -122.426244              98
# 210519               37.761047              -122.432642              56
# 210525               37.777791              -122.406432              36
# 210534               37.765052              -122.421866               5
# 210542               37.747300              -122.411403             144
# 210545               37.777791              -122.406432              97
# 210548               37.329732              -121.901782             310
# 210554               37.764765              -122.420091             356
#
#                                          end_station_name  \
# 0                               Fulton St at Bancroft Way
# 4                               5th St at San Salvador St
# 5            Powell St BART Station (Market St at 4th St)
# 7                                  Fruitvale BART Station
# 8                                  Fruitvale BART Station
# 9                             Cyril Magnin St at Ellis St
# 23                                   Market St at Park St
# 25                                 Webster St at Grove St
# 28                                Octavia Blvd at Page St
# 29                                Octavia Blvd at Page St
# 30                                  Sanchez St at 17th St
# 31                                  Sanchez St at 17th St
# 37                                Octavia Blvd at Page St
# 38           Powell St BART Station (Market St at 4th St)
# 40                                Beale St at Harrison St
# 42                                    Park Ave at Race St
# 43                                   Market St at Park St
# 45      Civic Center/UN Plaza BART Station (Market St ...
# 48                                         San Pablo Park
# 57                              Stanford Ave at Hollis St
# 60                                  Laguna St at Hayes St
# 66                                Octavia Blvd at Page St
# 67                                Octavia Blvd at Page St
# 70                                 29th St at Tiffany Ave
# 76                                    Folsom St at 2nd St
# 77                                    Folsom St at 2nd St
# 78                                  19th St at Mission St
# 84                         Valencia St at Cesar Chavez St
# 91                                 MacArthur BART Station
# 97                               19th Street BART Station
# ...                                                   ...
# 210391      San Francisco City Hall (Polk St at Grove St)
# 210398                      The Embarcadero at Sansome St
# 210403                             MacArthur BART Station
# 210422                            Beale St at Harrison St
# 210425                           Market St at Franklin St
# 210432                         Golden Gate Ave at Hyde St
# 210435  San Francisco Caltrain Station 2  (Townsend St...
# 210437                          Mississippi St at 17th St
# 210447                         Rhode Island St at 17th St
# 210453                              Sanchez St at 15th St
# 210457                             Pierce St at Haight St
# 210458                       Channing Way at Shattuck Ave
# 210472   Montgomery St BART Station (Market St at 2nd St)
# 210474                       The Embarcadero at Bryant St
# 210476                              Townsend St at 7th St
# 210504                            Parkmoor Ave at Race St
# 210505                            Parkmoor Ave at Race St
# 210506                               Horton St at 40th St
# 210511                             The Alameda at Bush St
# 210512                           Emeryville Public Market
# 210514                             24th St at Bartlett St
# 210515                              Milvia St at Derby St
# 210518                             Valencia St at 16th St
# 210519                                      Koshland Park
# 210525                                Folsom St at 3rd St
# 210534       Powell St BART Station (Market St at 5th St)
# 210542                                       Precita Park
# 210545                              14th St at Mission St
# 210548                          San Fernando St at 4th St
# 210554                        Valencia St at Clinton Park
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0                  37.867789            -122.265896     3112    Customer
# 4                  37.332039            -121.881766     1553    Customer
# 5                  37.786375            -122.404904     3503    Customer
# 7                  37.775232            -122.224498     1577    Customer
# 8                  37.775232            -122.224498     2534    Customer
# 9                  37.785881            -122.408915     9651    Customer
# 23                 37.332426            -121.890349     1838    Customer
# 25                 37.777053            -122.429558      649    Customer
# 28                 37.774018            -122.423809     9807    Customer
# 29                 37.774018            -122.423809    10036    Customer
# 30                 37.763242            -122.430675    11506    Customer
# 31                 37.763242            -122.430675     9789    Customer
# 37                 37.774018            -122.423809    10184    Customer
# 38                 37.786375            -122.404904    11185    Customer
# 40                 37.788059            -122.391865     9959    Customer
# 42                 37.326011            -121.912327    10548    Customer
# 43                 37.332426            -121.890349     9218    Customer
# 45                 37.781074            -122.411738     1586    Customer
# 48                 37.855783            -122.283127     3061    Customer
# 57                 37.838443            -122.288665     1135    Customer
# 60                 37.776435            -122.426244     2299    Customer
# 66                 37.774018            -122.423809     3150    Customer
# 67                 37.774018            -122.423809     9555  Subscriber
# 70                 37.744067            -122.421472    10344  Subscriber
# 76                 37.785377            -122.396906     9774    Customer
# 77                 37.785377            -122.396906      901    Customer
# 78                 37.760299            -122.418892    10046    Customer
# 84                 37.747998            -122.420219     9885    Customer
# 91                 37.828410            -122.266315     1339    Customer
# 97                 37.809013            -122.268247     2447    Customer
# ...                      ...                    ...      ...         ...
# 210391             37.778650            -122.418230      649    Customer
# 210398             37.804770            -122.403234     1651    Customer
# 210403             37.828410            -122.266315     1334  Subscriber
# 210422             37.788059            -122.391865     2848    Customer
# 210425             37.773793            -122.421239      997  Subscriber
# 210432             37.781650            -122.415408     3348    Customer
# 210435             37.776639            -122.395526      651    Customer
# 210437             37.764802            -122.394771     2215  Subscriber
# 210447             37.764478            -122.402570      495    Customer
# 210453             37.766219            -122.431060     1027    Customer
# 210457             37.771793            -122.433708     1759    Customer
# 210458             37.865847            -122.267443     1413    Customer
# 210472             37.789625            -122.400811     2298    Customer
# 210474             37.787168            -122.388098     2357    Customer
# 210476             37.771058            -122.402717     1772  Subscriber
# 210504             37.316736            -121.910005     7158    Customer
# 210505             37.316736            -121.910005     9179    Customer
# 210506             37.829705            -122.287610     3048    Customer
# 210511             37.331932            -121.904888      145    Customer
# 210512             37.840521            -122.293528     1242    Customer
# 210514             37.752105            -122.419724       40    Customer
# 210515             37.860125            -122.269384     1576    Customer
# 210518             37.765052            -122.421866      534    Customer
# 210519             37.773414            -122.427317     3246    Customer
# 210525             37.783830            -122.398870     1048    Customer
# 210534             37.783899            -122.408445      172    Customer
# 210542             37.747300            -122.411403     1890    Customer
# 210545             37.768265            -122.420110     3083    Customer
# 210548             37.335885            -121.885660     7176    Customer
# 210554             37.769188            -122.422285     2826    Customer
#
#         member_birth_year member_gender bike_share_for_all_trip
# 0                     NaN           NaN                      No
# 4                     NaN           NaN                      No
# 5                     NaN           NaN                      No
# 7                     NaN           NaN                      No
# 8                     NaN           NaN                      No
# 9                     NaN           NaN                      No
# 23                    NaN           NaN                      No
# 25                    NaN           NaN                      No
# 28                    NaN           NaN                      No
# 29                    NaN           NaN                      No
# 30                    NaN           NaN                      No
# 31                    NaN           NaN                      No
# 37                    NaN           NaN                      No
# 38                    NaN           NaN                      No
# 40                    NaN           NaN                      No
# 42                    NaN           NaN                      No
# 43                    NaN           NaN                      No
# 45                    NaN           NaN                      No
# 48                    NaN           NaN                      No
# 57                    NaN           NaN                      No
# 60                    NaN           NaN                      No
# 66                    NaN           NaN                      No
# 67                    NaN           NaN                      No
# 70                    NaN           NaN                      No
# 76                    NaN           NaN                      No
# 77                    NaN           NaN                      No
# 78                    NaN           NaN                      No
# 84                    NaN           NaN                      No
# 91                    NaN           NaN                      No
# 97                    NaN           NaN                      No
# ...                   ...           ...                     ...
# 210391                NaN           NaN                      No
# 210398                NaN           NaN                      No
# 210403                NaN           NaN                      No
# 210422                NaN           NaN                      No
# 210425                NaN           NaN                      No
# 210432                NaN           NaN                      No
# 210435                NaN           NaN                      No
# 210437                NaN           NaN                      No
# 210447                NaN           NaN                      No
# 210453                NaN           NaN                      No
# 210457                NaN           NaN                      No
# 210458                NaN           NaN                      No
# 210472                NaN           NaN                      No
# 210474                NaN           NaN                      No
# 210476                NaN           NaN                      No
# 210504                NaN           NaN                      No
# 210505                NaN           NaN                      No
# 210506                NaN           NaN                      No
# 210511                NaN           NaN                      No
# 210512                NaN           NaN                      No
# 210514                NaN           NaN                      No
# 210515                NaN           NaN                      No
# 210518                NaN           NaN                      No
# 210519                NaN           NaN                      No
# 210525                NaN           NaN                      No
# 210534                NaN           NaN                      No
# 210542                NaN           NaN                      No
# 210545                NaN           NaN                      No
# 210548                NaN           NaN                      No
# 210554                NaN           NaN                      No
#
# [39786 rows x 16 columns]

# %% [markdown]
# <br>
# Interestingly, except for 3 entries out of 39789 null entries, it seems that almost all members who chose not to provide their birth year also chose not to provide their gender (from the dimensions of the above output, bottom left corner). For the heck of it, let's get those 3 standalone entries:
# <br>

# %%
bikeshare_data[(bikeshare_data['member_birth_year'].isnull()) & (bikeshare_data['member_gender'].isnull() == False)]
# Out:
#         duration_sec                start_time                  end_time  \
# 130594          3885  2019-08-13 11:08:07.3250  2019-08-13 12:12:52.5070
# 199978           335  2019-08-02 14:03:06.6480  2019-08-02 14:08:41.9000
# 207859           348  2019-08-01 10:50:05.9120  2019-08-01 10:55:54.0120
#
#         start_station_id start_station_name  start_station_latitude  \
# 130594               408        MTL-ECO5-01                   45.51
# 199978               408        MTL-ECO5-01                   45.51
# 207859               408        MTL-ECO5-01                   45.51
#
#         start_station_longitude  end_station_id end_station_name  \
# 130594                   -73.57             408      MTL-ECO5-01
# 199978                   -73.57             408      MTL-ECO5-01
# 207859                   -73.57             408      MTL-ECO5-01
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 130594                 45.51                 -73.57     6733  Subscriber
# 199978                 45.51                 -73.57     6733  Subscriber
# 207859                 45.51                 -73.57     6733  Subscriber
#
#         member_birth_year member_gender bike_share_for_all_trip
# 130594                NaN         Other                      No
# 199978                NaN         Other                      No
# 207859                NaN         Other                      No

# %% [markdown]
# Wow, so it looks like 'Other' was chosen as the gender instead of the user having just skipped this information entry. Two possible explanations for this could be either laziness on the side of the user, or that the users may indeed prefer an alternative gender label. Moreover, these 3 ride entries are completely identical in terms of the start station and the end station, and the same bike was used as shown in 'bike_id' (only the duration and start/end time is different). It's fairly plausible that this is all just one user, who of all users given, only revealed their gender preference but not their birth year.

# %% [markdown]
# It's also notable to keep in mind that the entered birth/gender info in this dataset can be inaccurately entered by the users as well.

# %% [markdown]
# Let's see the proportion of null entries that are subscribers vs customers, compared to the rest of the dataset.

# %% [markdown]
# Null entries:

# %%
null_compare_or['user_type'].value_counts() / null_compare_or.shape[0]
# Out:
# Customer      0.929629
# Subscriber    0.070371
# Name: user_type, dtype: float64

# %% [markdown]
# <br>The rest of the dataset:

# %%
non_null = bikeshare_data.drop(index=null_compare_or.index)
non_null['user_type'].value_counts() / non_null.shape[0]
# Out:
# Subscriber    0.949372
# Customer      0.050628
# Name: user_type, dtype: float64

# %% [markdown]
# <br>Okay, so there isn't a notable distinction in user type between the null/not null entries.

# %% [markdown]
# We are given starting and ending latitude and longitude. Let's try to add another column containing the distance traveled for the ride:

# %%
# Function for calculating distance
# from math import sin, cos, sqrt, atan2, radians

def getDistance(lat1, lon1, lat2, lon2):
# approximate radius of earth in km
    R = 6373.0
    
    lat1 = np.radians(lat1)
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1
    
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

    distance = R * c
    return distance

# %%
# Test
print(getDistance(37.858473, -122.253253, 37.867789, -122.265896))
# Out:
# 1.5186677754886848

# %%
# Create new 'route_distance' column here indicating ride distance

# bikeshare_data['route_distance'] = bikeshare_data.apply(getDistance(lat1='start_station_latitude', lon1='start_station_longitude', lat2='end_station_latitude', lon2='end_station_longitude'), axis=1)
# df['col_3'] = df[['col_1','col_2']].apply(lambda x: f(*x), axis=1)
#df['col_3'] = df.apply(lambda x: get_sublist(x.col_1, x.col_2), axis=1)
bikeshare_data['route_distance'] = bikeshare_data.apply(lambda x: getDistance(x.start_station_latitude, x.start_station_longitude, x.end_station_latitude, x.end_station_longitude), axis=1)

# %%
# Cast start and end time to datetime format
bikeshare_data['start_time'] = pd.to_datetime(bikeshare_data['start_time'])
bikeshare_data['end_time'] = pd.to_datetime(bikeshare_data['end_time'])

# %%
# Create new 'member_age' column here indicating user age (if member birth year is present)
bikeshare_data['member_age'] = bikeshare_data.apply(lambda x: (x.start_time.year - x.member_birth_year) if (x.member_birth_year != np.nan) else np.nan, axis=1)

# %%
bikeshare_data.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         68145 2019-08-31 21:27:42.253 2019-09-01 16:23:27.492
# 1         53216 2019-08-31 22:34:17.512 2019-09-01 13:21:13.931
# 2         53182 2019-08-31 22:34:49.942 2019-09-01 13:21:12.457
# 3         75682 2019-08-31 14:22:02.278 2019-09-01 11:23:24.511
# 4         30849 2019-08-31 18:47:08.057 2019-09-01 03:21:17.697
#
#    start_station_id         start_station_name  start_station_latitude  \
# 0               249  Russell St at College Ave               37.858473
# 1               368       Myrtle St at Polk St               37.785434
# 2               368       Myrtle St at Polk St               37.785434
# 3               104          4th St at 16th St               37.767045
# 4               327  5th St at San Salvador St               37.332039
#
#    start_station_longitude  end_station_id           end_station_name  \
# 0              -122.253253             247  Fulton St at Bancroft Way
# 1              -122.419622              78        Folsom St at 9th St
# 2              -122.419622              78        Folsom St at 9th St
# 3              -122.390833             126                Esprit Park
# 4              -121.881766             327  5th St at San Salvador St
#
#    end_station_latitude  end_station_longitude  bike_id   user_type  \
# 0             37.867789            -122.265896     3112    Customer
# 1             37.773717            -122.411647     2440    Customer
# 2             37.773717            -122.411647     9743    Customer
# 3             37.761634            -122.390648    11418  Subscriber
# 4             37.332039            -121.881766     1553    Customer
#
#    member_birth_year member_gender bike_share_for_all_trip  route_distance  \
# 0                NaN           NaN                      No        1.518700
# 1             1993.0        Female                      No        1.479856
# 2             1995.0          Male                      No        1.479856
# 3             1993.0        Female                      No        0.602006
# 4                NaN           NaN                      No        0.000000
#
#    member_age
# 0         NaN
# 1        26.0
# 2        24.0
# 3        26.0
# 4         NaN

# %%
bikeshare_data.describe()
# Out:
#        duration_sec  start_station_id  start_station_latitude  \
# count  210563.00000     210563.000000           210563.000000
# mean      833.51472        144.829481               37.770058
# std      1928.22378        120.128023                0.102810
# min        61.00000          3.000000               37.311284
# 25%       376.00000         50.000000               37.770407
# 50%       593.00000        104.000000               37.780526
# 75%       914.00000        240.000000               37.795393
# max     85492.00000        459.000000               45.510000
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            210563.000000   210563.000000         210563.000000
# mean               -122.354407      140.921145             37.770268
# std                   0.217648      118.990674              0.102675
# min                -122.473658        3.000000             37.311284
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285       99.000000             37.780787
# 75%                -122.294837      233.000000             37.797280
# max                 -73.570000      459.000000             45.510000
#
#        end_station_longitude        bike_id  member_birth_year  \
# count          210563.000000  210563.000000      170774.000000
# mean             -122.353604    4048.755897        1984.964450
# std                 0.217245    3639.124465          10.037432
# min              -122.473658      12.000000        1878.000000
# 25%              -122.411306    1312.000000        1980.000000
# 50%              -122.397437    2629.000000        1987.000000
# 75%              -122.294837    9241.000000        1992.000000
# max               -73.570000   11945.000000        2001.000000
#
#        route_distance     member_age
# count   210563.000000  170774.000000
# mean         1.675576      34.035550
# std          1.060921      10.037432
# min          0.000000      18.000000
# 25%          0.931758      27.000000
# 50%          1.445961      32.000000
# 75%          2.190786      39.000000
# max         67.465996     141.000000

# %% [markdown]
# # Begin Univariate Exploration

# %% [markdown]
# This Lyft bikeshare dataset is set at a somewhat different level than other datasets in the course, such as the diamonds dataset. In the diamonds dataset, our analysis centered around being able to predict the price of a given diamond based on its association with other labels and variables in the dataset. In the Lyft dataset, the best dependent variable 'to be predicted' in my view would be the end station. Performing an analysis centered on where the user is most likely to travel would be ideal, so that Lyft would know to take action such as include additional bikes at a frequent station, remove stations that are less profitable to maintain, or even include promotions/deals for the user if there happens to be a popular business/destination near where the end station is situated.
# <br>
# <br>
# In addition, however, it is best in general to gain insight into behaviors patterns, or tendencies of the bikeshare users through this data; Understanding this will overall help make better decisions regarding consumer preferences.

# %% [markdown]
# #### Let's analyze the end stations variable:

# %%
end_station_counts = bikeshare_data['end_station_name'].value_counts()
end_station_counts
# Out:
# San Francisco Caltrain Station 2  (Townsend St at 4th St)          7249
# San Francisco Ferry Building (Harry Bridges Plaza)                 4495
# Montgomery St BART Station (Market St at 2nd St)                   4257
# Berry St at 4th St                                                 4076
# Market St at 10th St                                               3328
# Steuart St at Market St                                            3194
# Powell St BART Station (Market St at 4th St)                       3182
# The Embarcadero at Sansome St                                      3125
# Powell St BART Station (Market St at 5th St)                       2677
# 2nd St at Townsend St                                              2625
# Howard St at Beale St                                              2620
# San Francisco Caltrain (Townsend St at 4th St)                     2401
# Townsend St at 7th St                                              2288
# 4th St at Mission Bay Blvd S                                       2182
# Civic Center/UN Plaza BART Station (Market St at McAllister St)    2063
# 4th St at 16th St                                                  1957
# 8th St at Brannan St                                               1949
# 3rd St at Townsend St                                              1941
# Embarcadero BART Station (Beale St at Market St)                   1870
# Post St at Kearny St                                               1765
# The Embarcadero at Steuart St                                      1747
# Howard St at 8th St                                                1746
# Beale St at Harrison St                                            1695
# Rhode Island St at 17th St                                         1684
# MacArthur BART Station                                             1559
# Folsom St at 3rd St                                                1521
# Downtown Berkeley BART                                             1510
# 19th Street BART Station                                           1498
# Division St at Potrero Ave                                         1472
# 5th St at Folsom                                                   1400
#                                                                    ...
# Williams Ave at 3rd St                                               35
# Emory St at The Alameda                                              32
# Palm St at Willow St                                                 31
# Willow St at Vine St                                                 29
# Balboa Park BART Station                                             29
# Foothill Blvd at 42nd Ave                                            28
# 16th St Depot                                                        27
# Metro Dr at Technology Dr                                            27
# Judson Ave at Gennessee St                                           27
# Foothill Blvd at Fruitvale Ave                                       26
# Bestor Art Park                                                      26
# 17th St at Santa Clara St                                            21
# Goettingen St at Bacon St                                            20
# Gish Rd at 1st St                                                    18
# 23rd St at Taylor St                                                 18
# Auzerais Ave at Lincoln Ave                                          17
# Stockton Ave at Lenzen Ave                                           15
# 21st Ave at International Blvd                                       15
# Bird Ave at Coe Ave                                                  14
# 10th St at Empire St                                                 13
# Oak St at 1st St                                                     12
# 21st St at Santa Clara St                                            11
# Fruitvale Ave at International Blvd                                  11
# San Pedro St at Hedding St                                           11
# Foothill Blvd at Harrington Ave                                      10
# Kerley Dr at Rosemary St                                              9
# Williams Ave at Apollo St                                             8
# 1st St at Younger Ave                                                 7
# Utah St at 24th St                                                    7
# MTL-ECO5-01                                                           3
# Name: end_station_name, Length: 377, dtype: int64

# %% [markdown]
# At first, I thought I had noticed several duplicates in the end_station_name column, but I realized there were just a sheer large number of stations available, some with minute station name differences, such as Powell St BART Station (Market St at 4th St) and Powell St BART Station (Market St at 5th St).

# %% [markdown]
# There are 377 stations included as end stations. It seems like 'San Francisco Caltrain Station 2  (Townsend St at 4th St)' is the most frequent end destination numbers-wise, with 7249 users stopping there from August 5 to September 18, 2019, and 'Utah St at 24th St' is the least frequent (I could not find MTL-ECO5-01 as a valid location).

# %%
bikeshare_data['end_station_name'].value_counts().tail()
# Out:
# Kerley Dr at Rosemary St     9
# Williams Ave at Apollo St    8
# 1st St at Younger Ave        7
# Utah St at 24th St           7
# MTL-ECO5-01                  3
# Name: end_station_name, dtype: int64

# %% [markdown]
# It's really not worth doing a bar chart of this variable, due to the large number of stations present.

# %% [markdown]
# #### Let's analyze duration time (given in seconds):

# %%
bikeshare_data['duration_sec'].describe()
# Out:
# count    210563.00000
# mean        833.51472
# std        1928.22378
# min          61.00000
# 25%         376.00000
# 50%         593.00000
# 75%         914.00000
# max       85492.00000
# Name: duration_sec, dtype: float64

# %% [markdown]
# The mean ride duration time is 833 seconds (about 13 minutes) and the maximum duration time in this dataset is a whopping 85492 seconds (almost 24 hours!).

# %%
plt.hist(data=bikeshare_data, x='duration_sec');

# %% [markdown]
# Clearly, there are outliers present that are dragging the x-axis way high. The mean of this data is 833, so I'll use custom edges to narrow it down.

# %%
bin_edges = np.arange(0, 2500 + 10, 10)
plt.hist(data=bikeshare_data, x='duration_sec', bins=bin_edges);

# %%
bin_edges = np.arange(0, 1000 + 10, 10)
plt.hist(data=bikeshare_data, x='duration_sec', bins=bin_edges);

# %%
bin_edges = np.arange(1000, 2000 + 10, 10)
plt.hist(data=bikeshare_data, x='duration_sec', bins=bin_edges);

# %% [markdown]
# <br>
# There are no strange observations present in this distribution, which appears to be a fairly standard unimodal curve that is right-skewed.

# %% [markdown]
# ## Distribution of Ride Duration
# Ride durations vary widely, from 60 seconds to 60,000 seconds. Plotted on a logarithmic scale, the distribution of Ride duration takes on a symmetric unimodal shape.

# %%
log_bin_edges = np.arange(1.7, 4.0 + 0.02, 0.02)
plt.hist(np.log10(bikeshare_data['duration_sec']), bins=log_bin_edges)
locs, labels = plt.xticks()
ticks = [100, 300, 1000, 3000, 10000];
log_ticks = np.log10(ticks)
# print(log_ticks)
plt.xticks(log_ticks, ticks)
plt.xlabel('Ride Duration (Seconds)')
plt.title('Distribution of Ride Duration');

# %% [markdown]
# <br>
# Thanks to the sweeping long tail of the original distribution, we get a near-perfect bell curve of the data.

# %% [markdown]
# #### Let's analyze the start time:

# %% [markdown]
# <br>
# Analyzing the frequecies of start times or end times each day over a month can provide insight into certain events or trends that may have occured on a specific day or a range of days that may have led to an increase or drop in rides on that day. This information can be utilized by Lyft to offer relevant perks to riders, etc..

# %%
start_time_datetime = bikeshare_data['start_time'].sort_values(ascending=True)
start_time_datetime.describe()
# Out:
# count                         210563
# unique                        210550
# top       2019-08-19 08:36:36.680000
# freq                               2
# first     2019-08-01 00:04:27.953000
# last      2019-08-31 23:59:43.391000
# Name: start_time, dtype: object

# %% [markdown]
# Interesting, so it looks like we just have data ranging from the start to the end of october. This will make it much easier to deal with DateTime objects after casting, as we can just plot by the day of the month, treated as a discrete numeric variable.

# %%
start_time_datetime_day = start_time_datetime.apply(lambda x: x.day)
start_time_datetime_day.hist();

# %% [markdown]
# Yeah...Let's make the plot better

# %% [markdown]
# ## Adapted Bar Chart: No. of Rides per Day vs. Day of Month (August)
# It can be shown by the chart that there are greater number of rides during the weekdays (each peak of 5 days) compared to weekends.

# %%
plt.figure(figsize=(12, 6))
bin_edges = np.arange(0.5, 30.5 + 1.1, 1)
plt.hist(start_time_datetime_day, bins=bin_edges, rwidth=0.7)
plt.xticks(np.arange(1, 31 + 1, 1))
plt.xlabel('Day of the month of August 2019')
plt.ylabel('Number of rides')
plt.title('Number of Rides vs Day of Month');

# %% [markdown]
# The pattern seen here is interesting, but also obvious, as each wave of 5 high bars represent weekdays, which of course have higher frequencies than the 2 'weekend' bars that separate them. Generally, it appears that Mondays and Fridays usually contain lower frequencies compared to Tuesdays and Thursdays, which in turn are usually lower than Wednesdays. When it comes to the weekend, it appears that Saturday has generally slightly higher frequencies than Sunday.

# %%
end_time_datetime = bikeshare_data['start_time'].sort_values(ascending=True)
end_time_datetime.describe()
# Out:
# count                         210563
# unique                        210550
# top       2019-08-19 08:36:36.680000
# freq                               2
# first     2019-08-01 00:04:27.953000
# last      2019-08-31 23:59:43.391000
# Name: start_time, dtype: object

# %% [markdown]
# #### Let's analyze the end time:

# %% [markdown]
# <br>
# Similar to the start time, the end time data ranges for over a month. Let's plot it.

# %%
end_time_datetime_day = end_time_datetime.apply(lambda x: x.day)

# %%
plt.figure(figsize=(12, 6))
bin_edges = np.arange(.5, 31.5 + 1.1, 1)
plt.hist(end_time_datetime_day, bins=bin_edges, rwidth=0.7)
plt.xticks(np.arange(1, 30 + 1.1, 1))
plt.xlabel('Day of the month of August 2019')
plt.ylabel('Frequency of rides');

# %% [markdown]
# The notable patterns in the end time dataset are similar to that of the start time dataset above. Soon after plotting this, it appeared that it was exactly the same distribution as the start time dataset, as the position of all the bars all seem to be the same. To discern if there were indeed any differences in the frequencies between the 2 datasets (for example, if a rider rents out a bike but doesn't return it), I chose specific bar values and compared them:

# %%
# (start time == 4, end time == 4)
(start_time_datetime_day == 4).sum(), (end_time_datetime_day == 4).sum()
# Out:
# (3885, 3885)

# %%
# (start time == 13, end time == 13)
(start_time_datetime_day == 13).sum(), (end_time_datetime_day == 13).sum()
# Out:
# (7997, 7997)

# %%
# (start time == 20, end time == 20)
(start_time_datetime_day == 20).sum(), (end_time_datetime_day == 20).sum()
# Out:
# (8333, 8333)

# %%
4 in np.arange(0, 4)
# Out:
# False

# %% [markdown]
# <br>
# So as expected, there are minute value differences between the two frequency distributions.

# %% [markdown]
# Let's add the 'day of the month' to the dataset with respect to the start and end of the ride.<br>
# Let's also add the 'weekend/weekday' info to the dataset with respect to the start and end of the ride.

# %%
bikeshare_data['start_month_date'] = start_time_datetime_day
bikeshare_data['end_time_date'] = end_time_datetime_day

# True if weekday, False if weekend
bikeshare_data['start_is_weekday'] = start_time_datetime.apply(lambda x: (x.weekday() in np.arange(0, 5)))
bikeshare_data['end_is_weekday'] = end_time_datetime.apply(lambda x: (x.weekday() in np.arange(0, 5)))

# %%
bikeshare_data
# Out:
#         duration_sec              start_time                end_time  \
# 0              68145 2019-08-31 21:27:42.253 2019-09-01 16:23:27.492
# 1              53216 2019-08-31 22:34:17.512 2019-09-01 13:21:13.931
# 2              53182 2019-08-31 22:34:49.942 2019-09-01 13:21:12.457
# 3              75682 2019-08-31 14:22:02.278 2019-09-01 11:23:24.511
# 4              30849 2019-08-31 18:47:08.057 2019-09-01 03:21:17.697
# 5              17193 2019-08-31 20:52:40.744 2019-09-01 01:39:14.592
# 6               8959 2019-08-31 22:44:38.213 2019-09-01 01:13:57.248
# 7               9528 2019-08-31 22:04:15.446 2019-09-01 00:43:03.874
# 8               9542 2019-08-31 22:03:56.506 2019-09-01 00:42:59.328
# 9               4121 2019-08-31 23:26:05.751 2019-09-01 00:34:46.893
# 10              1624 2019-08-31 23:55:17.390 2019-09-01 00:22:22.132
# 11              1419 2019-08-31 23:58:09.400 2019-09-01 00:21:48.622
# 12              1617 2019-08-31 23:53:28.576 2019-09-01 00:20:25.871
# 13              1630 2019-08-31 23:52:41.664 2019-09-01 00:19:52.606
# 14              1527 2019-08-31 23:54:23.483 2019-09-01 00:19:51.387
# 15              1589 2019-08-31 23:53:18.987 2019-09-01 00:19:48.651
# 16              1157 2019-08-31 23:56:47.981 2019-09-01 00:16:05.457
# 17              1013 2019-08-31 23:49:19.235 2019-09-01 00:06:12.784
# 18               909 2019-08-31 23:50:55.512 2019-09-01 00:06:04.738
# 19               437 2019-08-31 23:58:34.852 2019-09-01 00:05:52.050
# 20              2042 2019-08-31 23:30:41.719 2019-09-01 00:04:44.441
# 21               219 2019-08-31 23:59:43.391 2019-09-01 00:03:22.918
# 22               686 2019-08-31 23:51:24.847 2019-09-01 00:02:51.265
# 23              1545 2019-08-31 23:36:30.818 2019-09-01 00:02:16.523
# 24              1537 2019-08-31 23:35:27.003 2019-09-01 00:01:04.912
# 25              1328 2019-08-31 23:38:52.140 2019-09-01 00:01:00.210
# 26               402 2019-08-31 23:52:02.943 2019-08-31 23:58:45.449
# 27               265 2019-08-31 23:53:42.193 2019-08-31 23:58:07.850
# 28               609 2019-08-31 23:47:21.423 2019-08-31 23:57:31.043
# 29               613 2019-08-31 23:47:16.048 2019-08-31 23:57:29.528
# ...              ...                     ...                     ...
# 210533           299 2019-08-01 01:04:05.869 2019-08-01 01:09:04.987
# 210534           603 2019-08-01 00:58:06.814 2019-08-01 01:08:09.902
# 210535           725 2019-08-01 00:52:19.937 2019-08-01 01:04:25.198
# 210536           400 2019-08-01 00:56:44.904 2019-08-01 01:03:25.502
# 210537          1974 2019-08-01 00:28:24.412 2019-08-01 01:01:19.226
# 210538           395 2019-08-01 00:47:54.189 2019-08-01 00:54:29.198
# 210539           342 2019-08-01 00:47:50.969 2019-08-01 00:53:33.428
# 210540          2474 2019-08-01 00:11:27.202 2019-08-01 00:52:42.196
# 210541           687 2019-08-01 00:34:24.170 2019-08-01 00:45:51.597
# 210542          1869 2019-08-01 00:12:22.380 2019-08-01 00:43:32.177
# 210543          1553 2019-08-01 00:08:48.554 2019-08-01 00:34:41.572
# 210544          1494 2019-08-01 00:09:40.882 2019-08-01 00:34:35.350
# 210545           548 2019-08-01 00:21:20.383 2019-08-01 00:30:28.908
# 210546           506 2019-08-01 00:21:57.593 2019-08-01 00:30:24.107
# 210547           144 2019-08-01 00:27:55.770 2019-08-01 00:30:20.560
# 210548           680 2019-08-01 00:17:22.342 2019-08-01 00:28:42.459
# 210549           286 2019-08-01 00:21:43.658 2019-08-01 00:26:30.073
# 210550           541 2019-08-01 00:17:14.337 2019-08-01 00:26:16.210
# 210551           376 2019-08-01 00:19:24.262 2019-08-01 00:25:40.412
# 210552           400 2019-08-01 00:17:12.872 2019-08-01 00:23:53.822
# 210553           492 2019-08-01 00:15:36.347 2019-08-01 00:23:48.432
# 210554           582 2019-08-01 00:13:55.809 2019-08-01 00:23:37.948
# 210555           663 2019-08-01 00:12:28.647 2019-08-01 00:23:32.492
# 210556           582 2019-08-01 00:11:45.025 2019-08-01 00:21:27.086
# 210557           517 2019-08-01 00:12:21.637 2019-08-01 00:20:59.568
# 210558           728 2019-08-01 00:07:37.039 2019-08-01 00:19:45.776
# 210559           761 2019-08-01 00:06:23.830 2019-08-01 00:19:05.550
# 210560           331 2019-08-01 00:08:28.757 2019-08-01 00:14:00.135
# 210561           111 2019-08-01 00:11:02.582 2019-08-01 00:12:54.134
# 210562           255 2019-08-01 00:04:27.953 2019-08-01 00:08:43.337
#
#         start_station_id                                 start_station_name  \
# 0                    249                          Russell St at College Ave
# 1                    368                               Myrtle St at Polk St
# 2                    368                               Myrtle St at Polk St
# 3                    104                                  4th St at 16th St
# 4                    327                          5th St at San Salvador St
# 5                     49                                S Park St at 3rd St
# 6                    323                                 Broadway at Kearny
# 7                    160                          West Oakland BART Station
# 8                    160                          West Oakland BART Station
# 9                      5       Powell St BART Station (Market St at 5th St)
# 10                   276                           Julian St at The Alameda
# 11                   259                            Addison St at Fourth St
# 12                   243                        Bancroft Way at College Ave
# 13                   243                        Bancroft Way at College Ave
# 14                   243                        Bancroft Way at College Ave
# 15                   243                        Bancroft Way at College Ave
# 16                    80                              Townsend St at 5th St
# 17                    14                              Clay St at Battery St
# 18                   296                              5th St at Virginia St
# 19                    10                         Washington St at Kearny St
# 20                   267                            Derby St at College Ave
# 21                   356                        Valencia St at Clinton Park
# 22                     3       Powell St BART Station (Market St at 4th St)
# 23                   282                               Market St at Park St
# 24                   371                         Lombard St at Columbus Ave
# 25                    17   Embarcadero BART Station (Beale St at Market St)
# 26                   239                      Bancroft Way at Telegraph Ave
# 27                     3       Powell St BART Station (Market St at 4th St)
# 28                    98                             Valencia St at 16th St
# 29                    98                             Valencia St at 16th St
# ...                  ...                                                ...
# 210533                21   Montgomery St BART Station (Market St at 2nd St)
# 210534                98                             Valencia St at 16th St
# 210535               116                          Mississippi St at 17th St
# 210536               365                             Turk St at Fillmore St
# 210537                33                         Golden Gate Ave at Hyde St
# 210538               256                           Hearst Ave at Euclid Ave
# 210539                29                      O'Farrell St at Divisadero St
# 210540                 9                             Broadway at Battery St
# 210541                87                               Folsom St at 13th St
# 210542               144                                       Precita Park
# 210543                43  San Francisco Public Library (Grove St at Hyde...
# 210544               104                                  4th St at 16th St
# 210545                62                        Victoria Manalo Draves Park
# 210546                62                        Victoria Manalo Draves Park
# 210547               183                           Telegraph Ave at 19th St
# 210548               312                           San Jose Diridon Station
# 210549               237                             Fruitvale BART Station
# 210550               246                              Berkeley Civic Center
# 210551                76                         McCoppin St at Valencia St
# 210552                56                                      Koshland Park
# 210553               271                                     San Pablo Park
# 210554               223                     16th St Mission BART Station 2
# 210555               284  Yerba Buena Center for the Arts (Howard St at ...
# 210556                62                        Victoria Manalo Draves Park
# 210557                62                        Victoria Manalo Draves Park
# 210558                67  San Francisco Caltrain Station 2  (Townsend St...
# 210559               151                               53rd St at Hollis St
# 210560                30     San Francisco Caltrain (Townsend St at 4th St)
# 210561               183                           Telegraph Ave at 19th St
# 210562               104                                  4th St at 16th St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.858473              -122.253253             247
# 1                    37.785434              -122.419622              78
# 2                    37.785434              -122.419622              78
# 3                    37.767045              -122.390833             126
# 4                    37.332039              -121.881766             327
# 5                    37.780760              -122.394989               3
# 6                    37.798014              -122.405950               8
# 7                    37.805318              -122.294837             237
# 8                    37.805318              -122.294837             237
# 9                    37.783899              -122.408445               4
# 10                   37.332233              -121.912517             276
# 11                   37.866249              -122.299371             268
# 12                   37.869360              -122.254337             239
# 13                   37.869360              -122.254337             239
# 14                   37.869360              -122.254337             239
# 15                   37.869360              -122.254337             239
# 16                   37.775235              -122.397437               5
# 17                   37.795001              -122.399970              60
# 18                   37.325998              -121.877120             296
# 19                   37.795393              -122.404770             324
# 20                   37.861804              -122.253569             171
# 21                   37.769188              -122.422285             223
# 22                   37.786375              -122.404904              92
# 23                   37.332426              -121.890349             282
# 24                   37.802746              -122.413579             139
# 25                   37.792251              -122.397086              55
# 26                   37.868813              -122.258764             255
# 27                   37.786375              -122.404904              36
# 28                   37.765052              -122.421866             411
# 29                   37.765052              -122.421866             411
# ...                        ...                      ...             ...
# 210533               37.789625              -122.400811              27
# 210534               37.765052              -122.421866               5
# 210535               37.764802              -122.394771             129
# 210536               37.780450              -122.431946             365
# 210537               37.781650              -122.415408             419
# 210538               37.875112              -122.260553             267
# 210539               37.782405              -122.439446             365
# 210540               37.798572              -122.400869              79
# 210541               37.769757              -122.415674             119
# 210542               37.747300              -122.411403             144
# 210543               37.778768              -122.415929              44
# 210544               37.767045              -122.390833              93
# 210545               37.777791              -122.406432              97
# 210546               37.777791              -122.406432              97
# 210547               37.808702              -122.269927             198
# 210548               37.329732              -121.901782             310
# 210549               37.775232              -122.224498             226
# 210550               37.869060              -122.270556             271
# 210551               37.771662              -122.422423              44
# 210552               37.773414              -122.427317             109
# 210553               37.855783              -122.283127             351
# 210554               37.764765              -122.420091             356
# 210555               37.784872              -122.400876             370
# 210556               37.777791              -122.406432              21
# 210557               37.777791              -122.406432              21
# 210558               37.776639              -122.395526              17
# 210559               37.836182              -122.287180             159
# 210560               37.776598              -122.395282              62
# 210561               37.808702              -122.269927             180
# 210562               37.767045              -122.390833             104
#
#                                          end_station_name  \
# 0                               Fulton St at Bancroft Way
# 1                                     Folsom St at 9th St
# 2                                     Folsom St at 9th St
# 3                                             Esprit Park
# 4                               5th St at San Salvador St
# 5            Powell St BART Station (Market St at 4th St)
# 6                           The Embarcadero at Vallejo St
# 7                                  Fruitvale BART Station
# 8                                  Fruitvale BART Station
# 9                             Cyril Magnin St at Ellis St
# 10                               Julian St at The Alameda
# 11                             Ellsworth St at Russell St
# 12                          Bancroft Way at Telegraph Ave
# 13                          Bancroft Way at Telegraph Ave
# 14                          Bancroft Way at Telegraph Ave
# 15                          Bancroft Way at Telegraph Ave
# 16           Powell St BART Station (Market St at 5th St)
# 17                                   8th St at Ringold St
# 18                                  5th St at Virginia St
# 19                    Union Square (Powell St at Post St)
# 20                                 Rockridge BART Station
# 21                         16th St Mission BART Station 2
# 22                                  Mission Bay Kids Park
# 23                                   Market St at Park St
# 24               Garfield Square (25th St at Harrison St)
# 25                                 Webster St at Grove St
# 26                            Virginia St at Shattuck Ave
# 27                                    Folsom St at 3rd St
# 28                                Octavia Blvd at Page St
# 29                                Octavia Blvd at Page St
# ...                                                   ...
# 210533                            Beale St at Harrison St
# 210534       Powell St BART Station (Market St at 5th St)
# 210535                             Harrison St at 20th St
# 210536                             Turk St at Fillmore St
# 210537                                 Fern St at Polk St
# 210538                            Derby St at College Ave
# 210539                             Turk St at Fillmore St
# 210540                               7th St at Brannan St
# 210541                                  18th St at Noe St
# 210542                                       Precita Park
# 210543  Civic Center/UN Plaza BART Station (Market St ...
# 210544                       4th St at Mission Bay Blvd S
# 210545                              14th St at Mission St
# 210546                              14th St at Mission St
# 210547                                          Snow Park
# 210548                          San Fernando St at 4th St
# 210549                     26th Ave at International Blvd
# 210550                                     San Pablo Park
# 210551  Civic Center/UN Plaza BART Station (Market St ...
# 210552                             17th St at Valencia St
# 210553                          10th St at University Ave
# 210554                        Valencia St at Clinton Park
# 210555                                Jones St at Post St
# 210556   Montgomery St BART Station (Market St at 2nd St)
# 210557   Montgomery St BART Station (Market St at 2nd St)
# 210558   Embarcadero BART Station (Beale St at Market St)
# 210559                               24th St at Market St
# 210560                        Victoria Manalo Draves Park
# 210561                           Telegraph Ave at 23rd St
# 210562                                  4th St at 16th St
#
#         end_station_latitude       ...         user_type  member_birth_year  \
# 0                  37.867789       ...          Customer                NaN
# 1                  37.773717       ...          Customer             1993.0
# 2                  37.773717       ...          Customer             1995.0
# 3                  37.761634       ...        Subscriber             1993.0
# 4                  37.332039       ...          Customer                NaN
# 5                  37.786375       ...          Customer                NaN
# 6                  37.799953       ...          Customer             1970.0
# 7                  37.775232       ...          Customer                NaN
# 8                  37.775232       ...          Customer                NaN
# 9                  37.785881       ...          Customer                NaN
# 10                 37.332233       ...        Subscriber             1969.0
# 11                 37.857490       ...        Subscriber             1976.0
# 12                 37.868813       ...          Customer             2000.0
# 13                 37.868813       ...          Customer             2000.0
# 14                 37.868813       ...          Customer             2000.0
# 15                 37.868813       ...          Customer             2001.0
# 16                 37.783899       ...        Subscriber             1983.0
# 17                 37.774520       ...        Subscriber             1993.0
# 18                 37.325998       ...        Subscriber             1993.0
# 19                 37.788300       ...        Subscriber             1995.0
# 20                 37.844279       ...        Subscriber             1995.0
# 21                 37.764765       ...        Subscriber             1992.0
# 22                 37.772301       ...        Subscriber             1981.0
# 23                 37.332426       ...          Customer                NaN
# 24                 37.751017       ...        Subscriber             1992.0
# 25                 37.777053       ...          Customer                NaN
# 26                 37.876573       ...        Subscriber             1999.0
# 27                 37.783830       ...        Subscriber             1973.0
# 28                 37.774018       ...          Customer                NaN
# 29                 37.774018       ...          Customer                NaN
# ...                      ...       ...               ...                ...
# 210533             37.788059       ...        Subscriber             1979.0
# 210534             37.783899       ...          Customer                NaN
# 210535             37.758862       ...        Subscriber             1984.0
# 210536             37.780450       ...        Subscriber             1985.0
# 210537             37.788197       ...        Subscriber             1984.0
# 210538             37.861804       ...        Subscriber             1997.0
# 210539             37.780450       ...        Subscriber             1985.0
# 210540             37.773492       ...        Subscriber             1993.0
# 210541             37.761047       ...          Customer             1984.0
# 210542             37.747300       ...          Customer                NaN
# 210543             37.781074       ...        Subscriber             1993.0
# 210544             37.770407       ...        Subscriber             1990.0
# 210545             37.768265       ...          Customer                NaN
# 210546             37.768265       ...        Subscriber             1992.0
# 210547             37.807813       ...        Subscriber             1992.0
# 210548             37.335885       ...          Customer                NaN
# 210549             37.781123       ...        Subscriber             1992.0
# 210550             37.855783       ...        Subscriber             1997.0
# 210551             37.781074       ...        Subscriber             1990.0
# 210552             37.763316       ...        Subscriber             1987.0
# 210553             37.869060       ...        Subscriber             1976.0
# 210554             37.769188       ...          Customer                NaN
# 210555             37.787327       ...        Subscriber             1996.0
# 210556             37.789625       ...        Subscriber             1994.0
# 210557             37.789625       ...        Subscriber             1995.0
# 210558             37.792251       ...        Subscriber             1983.0
# 210559             37.816060       ...        Subscriber             1982.0
# 210560             37.777791       ...        Subscriber             1994.0
# 210561             37.812678       ...        Subscriber             1993.0
# 210562             37.767045       ...        Subscriber             1990.0
#
#        member_gender  bike_share_for_all_trip route_distance member_age  \
# 0                NaN                       No       1.518700        NaN
# 1             Female                       No       1.479856       26.0
# 2               Male                       No       1.479856       24.0
# 3             Female                       No       0.602006       26.0
# 4                NaN                       No       0.000000        NaN
# 5                NaN                       No       1.072285        NaN
# 6             Female                       No       0.687348       49.0
# 7                NaN                       No       7.030328        NaN
# 8                NaN                       No       7.030328        NaN
# 9                NaN                       No       0.224218        NaN
# 10              Male                      Yes       0.000000       50.0
# 11            Female                       No       3.458834       43.0
# 12              Male                       No       0.393430       19.0
# 13              Male                       No       0.393430       19.0
# 14              Male                       No       0.393430       19.0
# 15              Male                       No       0.393430       18.0
# 16              Male                       No       1.365764       36.0
# 17              Male                       No       2.425679       26.0
# 18              Male                      Yes       0.000000       26.0
# 19              Male                       No       0.855392       24.0
# 20            Female                      Yes       1.954795       24.0
# 21              Male                       No       0.528439       27.0
# 22              Male                      Yes       1.881771       38.0
# 23               NaN                       No       0.000000        NaN
# 24              Male                       No       5.755704       27.0
# 25               NaN                       No       3.317579        NaN
# 26              Male                      Yes       1.279927       20.0
# 27              Male                       No       0.601281       46.0
# 28               NaN                       No       1.011799        NaN
# 29               NaN                       No       1.011799        NaN
# ...              ...                      ...            ...        ...
# 210533          Male                       No       0.805452       40.0
# 210534           NaN                       No       2.405661        NaN
# 210535        Female                       No       1.696760       35.0
# 210536          Male                       No       0.000000       34.0
# 210537          Male                       No       0.849038       35.0
# 210538          Male                       No       1.602266       22.0
# 210539          Male                       No       0.694204       34.0
# 210540          Male                       No       2.800532       26.0
# 210541          Male                       No       1.778917       35.0
# 210542           NaN                       No       0.000000        NaN
# 210543          Male                      Yes       0.448932       26.0
# 210544          Male                       No       0.375419       29.0
# 210545           NaN                       No       1.602799        NaN
# 210546          Male                       No       1.602799       27.0
# 210547          Male                       No       0.487406       27.0
# 210548           NaN                       No       1.581604        NaN
# 210549          Male                       No       0.993421       27.0
# 210550          Male                       No       1.843738       22.0
# 210551          Male                       No       1.406511       29.0
# 210552          Male                       No       1.219895       32.0
# 210553          Male                       No       1.730543       43.0
# 210554           NaN                       No       0.528439        NaN
# 210555          Male                       No       1.123918       23.0
# 210556          Male                       No       1.406069       25.0
# 210557          Male                       No       1.406069       24.0
# 210558          Male                       No       1.741902       36.0
# 210559        Female                       No       2.371914       37.0
# 210560          Male                       No       0.989187       25.0
# 210561          Male                       No       0.453759       26.0
# 210562          Male                       No       0.000000       29.0
#
#         start_month_date  end_time_date  start_is_weekday  end_is_weekday
# 0                     31             31             False           False
# 1                     31             31             False           False
# 2                     31             31             False           False
# 3                     31             31             False           False
# 4                     31             31             False           False
# 5                     31             31             False           False
# 6                     31             31             False           False
# 7                     31             31             False           False
# 8                     31             31             False           False
# 9                     31             31             False           False
# 10                    31             31             False           False
# 11                    31             31             False           False
# 12                    31             31             False           False
# 13                    31             31             False           False
# 14                    31             31             False           False
# 15                    31             31             False           False
# 16                    31             31             False           False
# 17                    31             31             False           False
# 18                    31             31             False           False
# 19                    31             31             False           False
# 20                    31             31             False           False
# 21                    31             31             False           False
# 22                    31             31             False           False
# 23                    31             31             False           False
# 24                    31             31             False           False
# 25                    31             31             False           False
# 26                    31             31             False           False
# 27                    31             31             False           False
# 28                    31             31             False           False
# 29                    31             31             False           False
# ...                  ...            ...               ...             ...
# 210533                 1              1              True            True
# 210534                 1              1              True            True
# 210535                 1              1              True            True
# 210536                 1              1              True            True
# 210537                 1              1              True            True
# 210538                 1              1              True            True
# 210539                 1              1              True            True
# 210540                 1              1              True            True
# 210541                 1              1              True            True
# 210542                 1              1              True            True
# 210543                 1              1              True            True
# 210544                 1              1              True            True
# 210545                 1              1              True            True
# 210546                 1              1              True            True
# 210547                 1              1              True            True
# 210548                 1              1              True            True
# 210549                 1              1              True            True
# 210550                 1              1              True            True
# 210551                 1              1              True            True
# 210552                 1              1              True            True
# 210553                 1              1              True            True
# 210554                 1              1              True            True
# 210555                 1              1              True            True
# 210556                 1              1              True            True
# 210557                 1              1              True            True
# 210558                 1              1              True            True
# 210559                 1              1              True            True
# 210560                 1              1              True            True
# 210561                 1              1              True            True
# 210562                 1              1              True            True
#
# [210563 rows x 22 columns]

# %% [markdown]
# #### Let's examine the start_station_name data:

# %%
bikeshare_data['start_station_name'].describe()
# Out:
# count                                                210563
# unique                                                  377
# top       San Francisco Caltrain Station 2  (Townsend St...
# freq                                                   5196
# Name: start_station_name, dtype: object

# %%
bikeshare_data['start_station_name'].value_counts().head()
# Out:
# San Francisco Caltrain Station 2  (Townsend St at 4th St)    5196
# Berry St at 4th St                                           4156
# San Francisco Ferry Building (Harry Bridges Plaza)           3714
# Market St at 10th St                                         3543
# Montgomery St BART Station (Market St at 2nd St)             3092
# Name: start_station_name, dtype: int64

# %% [markdown]
# The above cell provide the count of the data in the series (column), the number of unique categorical data, the most frequent category, and its respective frequency.

# %% [markdown]
# Let's look at the least frequent start station and its frequency:

# %%
bikeshare_data['start_station_name'].value_counts().tail()
# Out:
# 23rd St at Taylor St              11
# 1st St at Younger Ave              8
# 21st Ave at International Blvd     7
# MTL-ECO5-01                        3
# 16th St Depot                      2
# Name: start_station_name, dtype: int64

# %% [markdown]
# #### Let's examine the member age:

# %%
bikeshare_data['member_age'].describe()
# Out:
# count    170774.000000
# mean         34.035550
# std          10.037432
# min          18.000000
# 25%          27.000000
# 50%          32.000000
# 75%          39.000000
# max         141.000000
# Name: member_age, dtype: float64

# %%
plt.figure(figsize=(14, 3))
color = sb.color_palette()[0]
sb.boxplot(data=bikeshare_data, x='member_age');

# %% [markdown]
# While statistics such as the mean, median, and max values make sense for this category, it seems ridiculous to have users born before 1960 and even 1900 who choose to use bikeshare services, as seen by the outliers. It is clear in this case that this is abruptly incorrect data that is chosen by certain users, who were most likely in a hurry to register for the service and did not mind the inaccurate data.

# %% [markdown]
# Let's drop that possibly incorrect data by having a cutoff age of 70:

# %%
drop_ages = bikeshare_data[bikeshare_data['member_age'] > 70.0]
bikeshare_data.drop(index=drop_ages.index, inplace=True)

# %% [markdown]
# ## Boxplot: Rider Age
# This boxplot shows that the median age of Lyft Bikeshare members is 34, with a minimum of age 18, a median of 32, and a third quartile of 39. There are members that are well into the 50s, however.

# %%
plt.figure(figsize=(14, 3))
color = sb.color_palette()[0]
sb.boxplot(data=bikeshare_data, x='member_age');

# %% [markdown]
# #### Let's analyze the user type:

# %%
bikeshare_data['user_type'].value_counts()
# Out:
# Subscriber    164567
# Customer       45622
# Name: user_type, dtype: int64

# %%
bikeshare_data['user_type'].value_counts() / bikeshare_data['user_type'].shape[0]
# Out:
# Subscriber    0.782948
# Customer      0.217052
# Name: user_type, dtype: float64

# %%
bikeshare_data['user_type'].hist();

# %% [markdown]
# ## Customers vs Subscribers
# Of the rides present in this dataset, there are much higher frequencies of subscribers compared to customers.

# %%
plt.figure(figsize=(5, 5))
color = sb.color_palette()[0]
sb.countplot(data=bikeshare_data, x='user_type', color=color)
custCount = (bikeshare_data['user_type'] == 'Customer').sum()
subCount = (bikeshare_data['user_type'] == 'Subscriber').sum()
# print(custCount)
# print(subCount)
plt.rcParams['text.color'] = 'white';
plt.text(0-0.1, custCount - 10500, '{:.0f}'.format(custCount))
plt.text(1-0.1, subCount - 10500, '{:.0f}'.format(subCount))
plt.rcParams['text.color'] = 'black';
plt.xlabel('User Type')
plt.title('Frequency of Customers vs Subscribers');

# %%
plt.rcParams['text.color'] = 'black';

# %% [markdown]
# Substantially more users are subscribers than customers.

# %% [markdown]
# #### Let's analyze the member gender:

# %%
bikeshare_data['member_gender'].value_counts()
# Out:
# Male      128005
# Female     39979
# Other       2419
# Name: member_gender, dtype: int64

# %%
bikeshare_data['member_gender'].value_counts() / bikeshare_data['member_gender'].shape[0]
# Out:
# Male      0.609000
# Female    0.190205
# Other     0.011509
# Name: member_gender, dtype: float64

# %%
bikeshare_data['member_gender'].hist();

# %% [markdown]
# Many more males choose to use the bikeshare service than females or other gender identifications.

# %% [markdown]
# #### Mean and other statistics on the distance traveled by the users in this dataset:

# %%
bikeshare_data['route_distance'].describe()
# Out:
# count    210189.000000
# mean          1.675929
# std           1.061158
# min           0.000000
# 25%           0.931771
# 50%           1.445961
# 75%           2.191391
# max          67.465996
# Name: route_distance, dtype: float64

# %% [markdown]
# <br>
# The mean distance traveled in each ride is 1.67 miles, with the lowest value being 0 (bike is returned to the same station) and the maximum distance is a whopping 67 miles! Let's see its distribution:

# %%
bikeshare_data['route_distance'].hist();

# %% [markdown]
# Let's zoom in and make the plot more interpretable:

# %%
bin_edges = np.arange(0, 5, 0.1)
plt.hist(data=bikeshare_data, x='route_distance', bins=bin_edges);

# %% [markdown]
# There's a slight right skew present. Let's apply a logarithmic scale:

# %% [markdown]
# ## Ride Distance
# With a logarithmic scale applied, the ride distance takes on a relatively symmetric shape. There is a jump of frequencies on 0 miles, as several users choose to dock at the same bike station from where they left their bikes.

# %%
bin_edges = np.arange(0, 5, 0.1)
plt.hist(data=bikeshare_data, x='route_distance', bins=bin_edges)
plt.xscale('log')
labels = np.arange(0, 2, 1)
plt.xticks([0.1, 0.2, 0.5, 1, 2, 3, 4], ['0.1', '0.2', '0.5', '1', '2', '3', '4'])
# plt.xticks(labels, labels);
plt.xlabel('Ride Distance (miles)')
plt.title('Distribution of Ride Distance');

# %% [markdown]
# That's better!

# %% [markdown]
# # Bi-variate exploration

# %% [markdown]
# We will investigate relationships between pairs of these variables, particularly how each of them relate to the end station.

# %% [markdown]
# #### Let's investigate the relationship between the duration and the day of commute

# %%
bikeshare_data.columns
# Out:
# Index(['duration_sec', 'start_time', 'end_time', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type',
#        'member_birth_year', 'member_gender', 'bike_share_for_all_trip',
#        'route_distance', 'member_age', 'start_month_date', 'end_time_date',
#        'start_is_weekday', 'end_is_weekday'],
#       dtype='object')

# %%
plt.scatter(y=bikeshare_data['duration_sec'], x=bikeshare_data.start_time.dt.day)
plt.ylabel('Duration')
plt.xlabel('Day of month');

# %% [markdown]
# The data is not so clear with a scatterplot. Let's try a line plot with a mean duration estimate for each day:

# %%
plt.figure(figsize=(10, 5))
sb.barplot(data=bikeshare_data, x=bikeshare_data.start_time.dt.day, y='duration_sec', color=color);

# %% [markdown]
# Interesting, so it looks like there was increased average ride duration for users over the weekends. So even if there tend to be more users during weekdays, users rode the longest over the weekend.

# %% [markdown]
# When it comes to day of the week, so far, I have only been assuming that the jumps in the frequencies correspond to weekend/weekday differences. To be sure of this, let's quickly add a categorical day of the week variable from the datetime data to the plot:

# %% [markdown]
# ## Average Ride Duration vs Day of Month (Aug)
# It can be seen from the plot that users tend to ride for longer over the weekends (in blue) compared to weekdays (orange). This pattern seems to be kept relatively steady.

# %%
plt.figure(figsize=(10, 5))
sb.barplot(data=bikeshare_data, x=bikeshare_data.start_time.dt.day, y='duration_sec', color=color, hue='start_is_weekday', palette=sb.color_palette(n_colors=2), ci=None)
plt.legend(title='Weekday?', bbox_to_anchor=(1, 1))
plt.xlabel('Day of Month (August)')
plt.ylabel('Average Ride Duration (seconds)')
plt.title('Avg Ride Duration vs Day of Month');

# %% [markdown]
# Next, I would like to see if a particular end station is associated with having more users that are subscribers. There are 377 unique stations in the end station column, so it would not be ideal to take all of them into account for a visual. Instead, I will take the top 15 stations in terms of frequency, and go from there.

# %%
# Query the data that includes the top 15 end stations

# Array that contains the top 15 stations
top_15_end_stations = bikeshare_data['end_station_name'].value_counts().head(15).index.values
# Use a lambda function within a mask query to get the data that has one of the top 15 end stations as its end station
top_15_end_stations_data = bikeshare_data[bikeshare_data['end_station_name'].apply(lambda x: x in top_15_end_stations)]
top_15_end_stations_data.head()
# Out:
#     duration_sec              start_time                end_time  \
# 5          17193 2019-08-31 20:52:40.744 2019-09-01 01:39:14.592
# 16          1157 2019-08-31 23:56:47.981 2019-09-01 00:16:05.457
# 38           441 2019-08-31 23:40:32.035 2019-08-31 23:47:53.201
# 45           711 2019-08-31 23:31:15.550 2019-08-31 23:43:07.441
# 89           268 2019-08-31 23:02:27.431 2019-08-31 23:06:55.651
#
#     start_station_id                                start_station_name  \
# 5                 49                               S Park St at 3rd St
# 16                80                             Townsend St at 5th St
# 38                17  Embarcadero BART Station (Beale St at Market St)
# 45               324               Union Square (Powell St at Post St)
# 89                28                      The Embarcadero at Bryant St
#
#     start_station_latitude  start_station_longitude  end_station_id  \
# 5                37.780760              -122.394989               3
# 16               37.775235              -122.397437               5
# 38               37.792251              -122.397086               3
# 45               37.788300              -122.408531              44
# 89               37.787168              -122.388098              22
#
#                                      end_station_name  end_station_latitude  \
# 5        Powell St BART Station (Market St at 4th St)             37.786375
# 16       Powell St BART Station (Market St at 5th St)             37.783899
# 38       Powell St BART Station (Market St at 4th St)             37.786375
# 45  Civic Center/UN Plaza BART Station (Market St ...             37.781074
# 89                              Howard St at Beale St             37.789756
#
#          ...         user_type  member_birth_year member_gender  \
# 5        ...          Customer                NaN           NaN
# 16       ...        Subscriber             1983.0          Male
# 38       ...          Customer                NaN           NaN
# 45       ...          Customer                NaN           NaN
# 89       ...        Subscriber             1985.0          Male
#
#     bike_share_for_all_trip route_distance member_age  start_month_date  \
# 5                        No       1.072285        NaN                31
# 16                       No       1.365764       36.0                31
# 38                       No       0.948390        NaN                31
# 45                       No       0.851798        NaN                31
# 89                      Yes       0.643325       34.0                31
#
#     end_time_date  start_is_weekday  end_is_weekday
# 5              31             False           False
# 16             31             False           False
# 38             31             False           False
# 45             31             False           False
# 89             31             False           False
#
# [5 rows x 22 columns]

# %%
plt.rcParams['text.color'] = 'black'
sb.countplot(data=top_15_end_stations_data, y='end_station_name', hue='user_type');

# %% [markdown]
# Interesting, so it seems that seems that there are consistently more subscribers than customers at these stations with a relatively steady ratio, with one glaring exception: San Francisco Caltrain Station 2. This station has far more subscribers than any other station. This doesn't come as too much of a surprise, as this station also has the highest frequency as noted from the univariate investigation.

# %% [markdown]
# <br>
# Now, let's measure how many rides are for leisure and how many are used for commuting (see if end destination matches start destination).

# %% [markdown]
# ## Commute vs. Leisure Rides
# Whether a particular ride is considered a commute or a leisure ride depends on whether the end station matches the start station. If so, it is a leisure ride.

# %%
leisure_rides_sum = (bikeshare_data['start_station_name'] == bikeshare_data['end_station_name']).sum() #/ bikeshare_data['start_station_name'].shape[0]
commute_rides_sum = bikeshare_data['start_station_name'].shape[0] - leisure_rides_sum
arr = [leisure_rides_sum, commute_rides_sum]
# commute_rides_prop = 1 - leisure_rides_prop
plt.pie(arr, autopct='%1.1f%%', startangle=0, labels=('Leisure', 'Commute'))
plt.axis('equal');

# %% [markdown]
# Now, let's compare user type and gender:

# %% [markdown]
# ## Gender and User Type
# The plot below is an adapted bar chart measuring the frequency of each gender and the average number of customers of subscribers of each gender. There appear to be much more male subscribers than any other area. For each gender, the number of customers is a mere fraction compared to the number of subscribers present.

# %%
sb.countplot(data=bikeshare_data, x='member_gender', hue='user_type');

# %% [markdown]
# Next, let's see if users who choose to subscribe ride longer distances compared to those who haven't subscribed:

# %%
bikeshare_data.groupby('user_type')['route_distance'].mean().plot(kind='bar')

customer_mean_distance = bikeshare_data.groupby('user_type')['route_distance'].mean()['Customer']
subscriber_mean_distance = bikeshare_data.groupby('user_type')['route_distance'].mean()['Subscriber']

plt.text(0, customer_mean_distance - .25, '{:.3f}'.format(customer_mean_distance)) # 1.768
plt.text(1, subscriber_mean_distance - .25, '{:.3f}'.format(subscriber_mean_distance)) # 1.650

plt.ylabel('mean ride distance');

# %% [markdown]
# It looks like non-subscribers ride slightly more on average compared to subscribers.

# %%
sb.violinplot(data=bikeshare_data, x='user_type', y='route_distance')
plt.ylim(top=16, bottom=0);

# %% [markdown]
# Let's see if more distance is covered on average by users on weekdays compared to weekends:

# %%
# True if weekday, False if weekend
weekend_data = bikeshare_data[bikeshare_data['start_is_weekday'] == False]
weekday_data = bikeshare_data[bikeshare_data['start_is_weekday'] == True]

weekend_distance = weekend_data['route_distance'].mean()
weekday_distance = weekday_data['route_distance'].mean()

# %%
plt.bar(x=[0, 1], height=[weekend_distance, weekday_distance])
locs, labels = plt.xticks()
# plt.xticks(locs, '')
plt.xticks([0, 1], ['Weekend', 'Weekday'])
plt.ylabel('Mean Distance Traveled')
plt.rcParams['text.color'] = 'white'
plt.text(0, weekend_distance - .2, '{:.3f}'.format(weekend_distance)) 
plt.text(1, weekday_distance - .2, '{:.3f}'.format(weekday_distance));

# %% [markdown]
# On average, users ride slightly more on weekdays than weekends

# %%
plt.rcParams['text.color'] = 'black'

# %% [markdown]
# Let's plot the route distance against the ride duration for each ride in the dataset:

# %%
sb.regplot(data=bikeshare_data, x='duration_sec', y='route_distance');

# %% [markdown]
# Interesting, it looks like one outlier is present, which contains a route between 60 and 70 miles, which is dragging this plot way out of scope. Let's see if we can drop it.

# %%
drop_row = bikeshare_data[bikeshare_data['route_distance'] > 60]
bikeshare_data.drop(index=drop_row.index, inplace=True)
sb.regplot(data=bikeshare_data, x='duration_sec', y='route_distance', fit_reg=False, x_jitter=0.7, y_jitter=0.7, scatter_kws={'alpha':1/4});

# %% [markdown]
# I want to know the age range of who rides for the most time/longest distance. This plot will be shown in the multivariate section.

# %% [markdown]
# Contrary to basic logic, ride duration in this case does not necessarily have a linear relationship with route distance traveled. A longer ride doesn't mean more distance is covered.

# %%
bikeshare_data.iloc[1]
# Out:
# duration_sec                                    53216
# start_time                 2019-08-31 22:34:17.512000
# end_time                   2019-09-01 13:21:13.931000
# start_station_id                                  368
# start_station_name               Myrtle St at Polk St
# start_station_latitude                        37.7854
# start_station_longitude                       -122.42
# end_station_id                                     78
# end_station_name                  Folsom St at 9th St
# end_station_latitude                          37.7737
# end_station_longitude                        -122.412
# bike_id                                          2440
# user_type                                    Customer
# member_birth_year                                1993
# member_gender                                  Female
# bike_share_for_all_trip                            No
# route_distance                                1.47986
# member_age                                         26
# start_month_date                                   31
# end_time_date                                      31
# start_is_weekday                                False
# end_is_weekday                                  False
# Name: 1, dtype: object

# %% [markdown]
# # Multi-variate exploration

# %% [markdown]
# Our focus is on patterns involving end stations, so let's compare the average ages of users for the top 15 stations to that of the lowest 15 stations.

# %%
# Get the top 15 stations

top_15_end_stations_data.head(2)
# Out:
#     duration_sec              start_time                end_time  \
# 5          17193 2019-08-31 20:52:40.744 2019-09-01 01:39:14.592
# 16          1157 2019-08-31 23:56:47.981 2019-09-01 00:16:05.457
#
#     start_station_id     start_station_name  start_station_latitude  \
# 5                 49    S Park St at 3rd St               37.780760
# 16                80  Townsend St at 5th St               37.775235
#
#     start_station_longitude  end_station_id  \
# 5               -122.394989               3
# 16              -122.397437               5
#
#                                 end_station_name  end_station_latitude  \
# 5   Powell St BART Station (Market St at 4th St)             37.786375
# 16  Powell St BART Station (Market St at 5th St)             37.783899
#
#          ...         user_type  member_birth_year member_gender  \
# 5        ...          Customer                NaN           NaN
# 16       ...        Subscriber             1983.0          Male
#
#     bike_share_for_all_trip route_distance member_age  start_month_date  \
# 5                        No       1.072285        NaN                31
# 16                       No       1.365764       36.0                31
#
#     end_time_date  start_is_weekday  end_is_weekday
# 5              31             False           False
# 16             31             False           False
#
# [2 rows x 22 columns]

# %%
# Get the lowest 15 stations

# Array that contains the lowest 15 stations
low_15_end_stations = bikeshare_data['end_station_name'].value_counts().tail(15).index.values
# Use a lambda function within a mask query to get the data that has one of the top 15 end stations as its end station
low_15_end_stations_data = bikeshare_data[bikeshare_data['end_station_name'].apply(lambda x: x in low_15_end_stations)]
low_15_end_stations_data.head(2)
# Out:
#      duration_sec              start_time                end_time  \
# 717           718 2019-08-31 19:02:26.462 2019-08-31 19:14:24.506
# 719           674 2019-08-31 19:03:04.390 2019-08-31 19:14:19.366
#
#      start_station_id               start_station_name  \
# 717               313  Almaden Blvd at San Fernando St
# 719               313  Almaden Blvd at San Fernando St
#
#      start_station_latitude  start_station_longitude  end_station_id  \
# 717               37.331415                -121.8932             427
# 719               37.331415                -121.8932             427
#
#                 end_station_name  end_station_latitude       ...        \
# 717  Auzerais Ave at Lincoln Ave             37.320969       ...
# 719  Auzerais Ave at Lincoln Ave             37.320969       ...
#
#      user_type  member_birth_year member_gender  bike_share_for_all_trip  \
# 717   Customer                NaN           NaN                       No
# 719   Customer                NaN           NaN                       No
#
#     route_distance member_age  start_month_date  end_time_date  \
# 717       1.770031        NaN                31             31
# 719       1.770031        NaN                31             31
#
#      start_is_weekday  end_is_weekday
# 717             False           False
# 719             False           False
#
# [2 rows x 22 columns]

# %%
plt.subplot(1, 2, 1)

# %% [markdown]
# I want to know the age range of who rides for the most time/longest distance. This plot will be shown in the multivariate section.

# %%
sample_data = bikeshare_data.sample(5000)
g = sb.FacetGrid(data=sample_data, hue='user_type', size=5)
g.map(plt.scatter, 'duration_sec', 'route_distance')
g.add_legend();

# %% [markdown]
# Narrow the x limit:

# %%
g = sb.FacetGrid(data=sample_data, hue='user_type', size=5)
g.map(plt.scatter, 'duration_sec', 'route_distance')
g.add_legend()
plt.xlim(xmin=0, xmax=10000);

# %% [markdown]
# Instead of narrowing the limit, <br>
# Let's try a log Scale transformation on x axis:

# %%
g = sb.FacetGrid(data=sample_data, hue='user_type', size=5)
g.map(plt.scatter, 'duration_sec', 'route_distance')
g.add_legend()
plt.xscale('log');

# %% [markdown]
# Let's try cube root scale transformation on x axis:

# %%
def cbrt_trans(x, inverse=False):
    '''Transformation helper function'''
    if not inverse:
        return np.cbrt(x)
    else:
        return x**3

# %% [markdown]
# ## Ride Distance(miles) vs Duration(seconds)
# This scatterplot with a color-encoded variable for the user type shows that there is a correlation present with the riding distance compared with the amount of time spent on the bike. A cube-root scale transformation applied to this plot helps show the data increasing in a more linear fashion.

# %%
trans_data_copy = sample_data.copy()
temp_trans_duration = trans_data_copy['duration_sec'].apply(cbrt_trans)
trans_data_copy['duration_sec'] = temp_trans_duration
g = sb.FacetGrid(data=trans_data_copy, hue='user_type', size=5)
g.map(plt.scatter, 'duration_sec', 'route_distance')
tick_locs = np.arange(0, trans_data_copy['duration_sec'].max()+10, 10)
plt.xticks(tick_locs, cbrt_trans(tick_locs, inverse=True).astype(int))
g.add_legend();

# %% [markdown]
# I feel that the cube root transformation helps to better accurately judge the distribution of route distance vs duration.
